# %% [markdown]
# # Detail working designs, etc.

# %% [markdown]
# ### Imports

# %%
# %load_ext lab_black
# Python standard library
from glob import glob
import os
import socket
import sys

# 3rd party library imports
import dask
import matplotlib.pyplot as plt
import pandas as pd
import pyrosetta
import numpy as np
import scipy
import seaborn as sns
from tqdm.auto import tqdm  # jupyter compatible progress bar

tqdm.pandas()  # link tqdm to pandas
# Notebook magic
# save plots in the notebook
# %matplotlib inline
# reloads modules automatically before executing cells
# %load_ext autoreload
# %autoreload 2
print(f"running in directory: {os.getcwd()}")  # where are we?
print(f"running on node: {socket.gethostname()}")  # what node are we on?
# Out:
# running in directory: /mnt/projects/crispy_shifty/projects/crispy_crispies
# running on node: gpu18

# %% [markdown]
# ### Set working directory to the root of the crispy_shifty repo

# %%
os.chdir("/projects/crispy_shifty")

# %% [markdown]
# ### Start on some from Flo

# %%
pdb = "/projects/crispy_shifty/projects/crispy_crispies/data/pdbs/A4_in.pdb"
basename = "A4"

sys.path.insert(0, "/projects/crispy_shifty")
from projects.crispy_crispies.deployables import detail

simulation_name = "10_detail"
output_path = os.path.join(os.getcwd(), f"projects/crispy_crispies/{simulation_name}")
os.makedirs(output_path, exist_ok=True)
pdbs_path = os.path.join(output_path, "pdbs")
os.makedirs(pdbs_path, exist_ok=True)

pposes = detail(
    None,
    pdb_path=pdb,
    max_recycles=3,
    models="1",
    rmsd_cutoff=True,  # TODO rmsd_cutoff
    neighborhood_distance=7,
    resis="50,139,148",
    num_sequences=8,
)

for i, p in enumerate(pposes):
    p.pose.dump_pdb(os.path.join(pdbs_path, f"{basename}_{str(i).zfill(4)}.pdb"))
# Out:
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# Scores may be absent or incorrectly formatted
# 0.08 min: Redesigning with MPNN
#
# ----------------------------------------
# pssm_jsonl is NOT loaded
# ----------------------------------------
# omit_AA_jsonl is NOT loaded
# ----------------------------------------
# bias_AA_jsonl is NOT loaded
# ----------------------------------------
# tied_positions_jsonl is NOT loaded
# ----------------------------------------
# bias by residue dictionary is not loaded, or not provided
# ----------------------------------------
# discarded {'bad_chars': 0, 'too_long': 0, 'bad_seq_length': 0}
# ----------------------------------------
# Number of edges: 48
# Training noise level: 0.1A
# Generating sequences for: tmp
# 8 sequences of length 197 generated in 0.3164 seconds
#
# 0.29 min: MPNN design complete, updating pose datacache
# 0.29 min: Filtering sequences with AF2
# 0.29 min: Setting up for AF2
# 0.29 min: Running AF2
# Warning: use "from pymol import cmd" instead of "import cmd"
# using  gpu
# =======================================================================================
# WARNING: Your querys are shorter than 400 residues. This is a very small protein.
# You may want to use the CPU to conserve GPU resources for those who need them.
# Remember that you can launch far more jobs in parallel on CPUs than you can on GPUs...
# See this example of how prediction time scales on CPU vs GPU:
# https://docs.google.com/spreadsheets/d/1jTGITpIx6fJehAplUkXtePOp7me3Dpq_pPKHn68F7XY
# =======================================================================================
# mpnn_seq_0000 model_1_ptm_seed_0 recycles:3 tol:0.45 mean_plddt:86.00 pTMscore:0.81 rmsd_to_reference:5.14 elapsed time (s): 195.70663213729858
# mpnn_seq_0001 model_1_ptm_seed_0 recycles:3 tol:0.50 mean_plddt:84.12 pTMscore:0.81 rmsd_to_reference:1.57 elapsed time (s): 14.873440027236938
# mpnn_seq_0002 model_1_ptm_seed_0 recycles:3 tol:0.56 mean_plddt:85.33 pTMscore:0.81 rmsd_to_reference:1.67 elapsed time (s): 14.94568920135498
# mpnn_seq_0003 model_1_ptm_seed_0 recycles:3 tol:0.59 mean_plddt:84.90 pTMscore:0.81 rmsd_to_reference:5.12 elapsed time (s): 14.871951818466187
# mpnn_seq_0004 model_1_ptm_seed_0 recycles:3 tol:0.60 mean_plddt:84.29 pTMscore:0.81 rmsd_to_reference:1.88 elapsed time (s): 16.7898530960083
# mpnn_seq_0005 model_1_ptm_seed_0 recycles:3 tol:0.53 mean_plddt:86.34 pTMscore:0.82 rmsd_to_reference:1.59 elapsed time (s): 15.493590593338013
# mpnn_seq_0006 model_1_ptm_seed_0 recycles:3 tol:0.50 mean_plddt:85.79 pTMscore:0.81 rmsd_to_reference:1.87 elapsed time (s): 14.96967625617981
# mpnn_seq_0007 model_1_ptm_seed_0 recycles:3 tol:0.49 mean_plddt:82.61 pTMscore:0.79 rmsd_to_reference:1.07 elapsed time (s): 14.93020749092102
# mpnn_seq_0008 model_1_ptm_seed_0 recycles:3 tol:0.29 mean_plddt:80.37 pTMscore:0.77 rmsd_to_reference:1.72 elapsed time (s): 14.970934391021729
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Input: mpnn_seq_0000:   0%|          | 0/9 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:04<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [03:03<00:00, 183.56s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [03:05<00:00, 185.63s/it]
#
# Input: mpnn_seq_0000:  11%|█         | 1/9 [03:05<24:46, 185.86s/it]
# Input: mpnn_seq_0001:  11%|█         | 1/9 [03:05<24:46, 185.86s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:13<00:00, 13.58s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.75s/it]
#
# Input: mpnn_seq_0001:  22%|██▏       | 2/9 [03:20<09:56, 85.28s/it]
# Input: mpnn_seq_0002:  22%|██▏       | 2/9 [03:20<09:56, 85.28s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:13<00:00, 13.66s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.83s/it]
#
# Input: mpnn_seq_0002:  33%|███▎      | 3/9 [03:35<05:18, 53.16s/it]
# Input: mpnn_seq_0003:  33%|███▎      | 3/9 [03:35<05:18, 53.16s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:13<00:00, 13.58s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.76s/it]
#
# Input: mpnn_seq_0003:  44%|████▍     | 4/9 [03:50<03:10, 38.05s/it]
# Input: mpnn_seq_0004:  44%|████▍     | 4/9 [03:50<03:10, 38.05s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.51s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:16<00:00, 16.68s/it]
#
# Input: mpnn_seq_0004:  56%|█████▌    | 5/9 [04:07<02:01, 30.38s/it]
# Input: mpnn_seq_0005:  56%|█████▌    | 5/9 [04:07<02:01, 30.38s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.12s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:15<00:00, 15.30s/it]
#
# Input: mpnn_seq_0005:  67%|██████▋   | 6/9 [04:22<01:15, 25.32s/it]
# Input: mpnn_seq_0006:  67%|██████▋   | 6/9 [04:22<01:15, 25.32s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:13<00:00, 13.67s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.86s/it]
#
# Input: mpnn_seq_0006:  78%|███████▊  | 7/9 [04:37<00:43, 21.94s/it]
# Input: mpnn_seq_0007:  78%|███████▊  | 7/9 [04:37<00:43, 21.94s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:13<00:00, 13.64s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.81s/it]
#
# Input: mpnn_seq_0007:  89%|████████▉ | 8/9 [04:52<00:19, 19.71s/it]
# Input: mpnn_seq_0008:  89%|████████▉ | 8/9 [04:52<00:19, 19.71s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/1 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:13<00:00, 13.68s/it]
# Running model_1_ptm_seed_0: 100%|██████████| 1/1 [00:14<00:00, 14.86s/it]
#
# Input: mpnn_seq_0008: 100%|██████████| 9/9 [05:07<00:00, 18.23s/it]
# Input: mpnn_seq_0008: 100%|██████████| 9/9 [05:07<00:00, 34.19s/it]
#
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 168
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue THR:CtermProteinFull 197
# 5.76 min: AF2 complete, updating pose datacache
# 5.76 min: Adding passing sequences back into pose
