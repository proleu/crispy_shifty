# %%
working_dimers = ['CSD20', 'CSD23', 'CSD25', 'CSD26']

with open('../af2/good_models.list', 'r') as f:
    good_models = f.read().splitlines()

# working_models = [x for x in good_models if x.split('/')[-1][:5] in working_dimers]

working_models = []

for working_dimer in working_dimers:
    models_all = [x for x in good_models if x.split('/')[-1][:5] == working_dimer]
    models_A = [x for x in models_all if x.split('/')[-1].startswith(working_dimer + 'A_')]
    models_B = [x for x in models_all if x.split('/')[-1].startswith(working_dimer + 'B_')]
    models_AB = [x for x in models_all if x.split('/')[-1].startswith(working_dimer + 'AB_')]

    working_models.append([models_A, models_B, models_AB])

# %%
import pyrosetta
pyrosetta.distributed.maybe_init(**{
    "options": "-corrections::beta_nov16 true",
    "extra_options":{
        "-out:level": "100",
}})

# %%
# make all combinations of backbones from different AF2 models for each SEC-validated heterodimer
# this will provide MPNN with a good set of backbone diversity for MSD

from itertools import product
from copy import deepcopy

import sys
sys.path.insert(0, '/home/broerman/projects/crispy_shifty/')
from crispy_shifty.protocols.states import yeet_pose_xyz

sw = pyrosetta.rosetta.protocols.simple_moves.SwitchChainOrderMover()
sw.chain_order('1234')

for models_A_B_AB, working_dimer in zip(working_models, working_dimers):

    poses_A_B_AB = []
    for model_group, yeet_coords, split in zip(models_A_B_AB, [(1,0,0), (0,1,0), None], [False,False,True]):
        pose_group = []
        for pdb_fname in model_group:
            pose = pyrosetta.pose_from_pdb(pdb_fname)
            model_num = pdb_fname.split('/')[-1].split('_')[2]

            if yeet_coords:
                pose = yeet_pose_xyz(pose, yeet_coords)

            if split:
                pose = pose.split_by_chain()

            pose_group.append((pose, model_num))
        poses_A_B_AB.append(pose_group)

    for (pose_A, model_A), (pose_B, model_B), (poses_AB, model_AB) in product(*poses_A_B_AB):
        combined_pose = deepcopy(pose_A)
        pyrosetta.rosetta.core.pose.append_pose_to_pose(combined_pose, deepcopy(pose_B), True)
        pyrosetta.rosetta.core.pose.append_pose_to_pose(combined_pose, deepcopy(poses_AB[1]), True)
        pyrosetta.rosetta.core.pose.append_pose_to_pose(combined_pose, deepcopy(poses_AB[2]), True)
        sw.apply(combined_pose)
        combined_pose.dump_pdb('backbone_combos/' + working_dimer + '_' + model_A + model_B + model_AB + '.pdb')

# %%
import pyrosetta.distributed.io as io

import sys
sys.path.insert(0, '/home/broerman/projects/crispy_shifty/')
from crispy_shifty.protocols.mpnn import mpnn_hinge_dimers, MPNNDesign

ppose_in = io.pose_from_file('backbone_combos/CSD20_111.pdb')

pposes = mpnn_hinge_dimers(
    packed_pose_in = ppose_in,
    num_sequences = 10,
    batch_size = 10,
    **{
        "mpnn_design_area": 'scan'
    }
)

# iterate first since mpnn_hinge_dimers returns a generator
poses = []
for ppose in pposes:
    poses.append(io.to_pose(ppose))

# then once all sequences are generated, build the structures
mpnn_design = MPNNDesign()
for design_area, pose in zip(['full', 'interface', 'neighborhood'], poses):
    # print(pose)
    for j, mpnn_pose in enumerate(mpnn_design.generate_all_poses(pose)):
        mpnn_pose.dump_pdb(f'test/CSD20_111_mpnn_{design_area}_{j}.pdb')

# %%
# mpnn msd uses >5g of RAM sometimes
# it's also multithreaded which is pretty cool

# %%
from glob import glob

task_lines = []

for bb_fname in sorted(glob('/home/broerman/projects/CSD/round_2/mpnn/backbone_combos/*.pdb')):
    task_lines.append(f"/home/broerman/projects/CSD/round_2/mpnn/mpnn_design_backbones.py {bb_fname}\n")

with open('mpnn_design_backbones.tasks', 'w') as f:
    f.write(''.join(task_lines))

print('sbatch -a 1-$(cat mpnn_design_backbones.tasks | wc -l) mpnn_design_backbones.sh')
# Out:
# sbatch -a 1-$(cat mpnn_design_backbones.tasks | wc -l) mpnn_design_backbones.sh

# %%
# alphafold all the unique sequences

from Bio import SeqIO
from collections import defaultdict
from glob import glob
from IPython.utils.io import capture_output
from tqdm.auto import tqdm

len_seq_path = defaultdict(dict)

for file_path in tqdm(sorted(glob(f'/home/broerman/projects/CSD/round_2/mpnn/mpnn_designs/*.pdb'))):
    sequence = ''
    with capture_output() as captured: # otherwise memory overloads lol
        for i, record in enumerate(SeqIO.parse(file_path, 'pdb-atom')):
            sequence += str(record.seq)

    if sequence not in len_seq_path[len(sequence)]:
        len_seq_path[len(sequence)][sequence] = file_path
# Out:
# 100%|██████████| 4110/4110 [17:14<00:00,  3.97it/s]

# %%
import json
json.dump(len_seq_path, open('mpnn_designs_unique_seqs.json', 'w'))

# %%
import json
len_seq_path = json.load(open('mpnn_designs_unique_seqs.json', 'r'))

# %%
num_seqs = 0
for length, seq_path in len_seq_path.items():
    num_seqs += len(seq_path)
print(num_seqs)
# Out:
# 4083

# %%
# look at distribution of percent sequence identity of each design to the original, as well as the sequence diversity of all designs
from collections import defaultdict

# bin seqs by parent backbone and extent of redesign

all_seqs_designs = {}
binned_sequences = defaultdict(list)

for length, seqs_designs in len_seq_path.items():
    all_seqs_designs.update(seqs_designs)

for seq, path in all_seqs_designs.items():
    path_split = path.split('/')[-1].split('_')
    design_id = path_split[0] + '_' + path_split[2]
    binned_sequences[design_id].append(seq)

# %%
from Bio import SeqIO
from glob import glob
from IPython.utils.io import capture_output

len_seq_path = defaultdict(dict)

orig_seqs = {}

for design_id in binned_sequences.keys():
    file_path = glob('/home/broerman/projects/CSD/round_2/mpnn/backbone_combos/' + design_id.split('_')[0] + '*.pdb')[0]
    sequence = ''
    with capture_output() as captured: # otherwise memory overloads lol
        for i, record in enumerate(SeqIO.parse(file_path, 'pdb-atom')):
            sequence += str(record.seq)
    orig_seqs[design_id] = sequence

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 4, figsize=(12, 9))

for (design_id, seqs), ax in zip(binned_sequences.items(), axs.T.flatten()):
    orig_seq = orig_seqs[design_id]
    seq_len = len(orig_seq)
    similarities = []
    for seq in seqs:
        similarities.append(sum([seq[i] == orig_seq[i] for i in range(seq_len)]) / seq_len)

    ax.hist(similarities)
    ax.set_title(design_id)
    
fig.tight_layout()
fig.savefig('similarities_to_input.png')

# %%
# how do you come up with a number for the sequence diversity of all designs against each other?
# for each design, compute its sequence diversity against all other designs, average them, then average all these averages

# could find a smarter way to do this with matrix multiplication, but ehh

import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(3, 4, figsize=(12, 9))

for (design_id, seqs), ax in zip(binned_sequences.items(), axs.T.flatten()):
    mean_similarities = []
    for base_seq in seqs:
        seq_len = len(base_seq)
        mean_similarity = np.mean([np.sum([seq[i] == base_seq[i] for i in range(seq_len)]) / seq_len for seq in seqs])
        mean_similarities.append(mean_similarity)
    ax.hist(mean_similarities)
    ax.set_title(design_id)
    print(design_id, np.mean(mean_similarities))

fig.tight_layout()
fig.savefig('similarities_among_designs.png')
# Out:
# CSD20_full 0.7519694275067751
# CSD20_interface 0.9397585433025435
# CSD20_neighborhood 0.8635890921409214
# CSD23_full 0.73463056
# CSD23_interface 0.9441264000000001
# CSD23_neighborhood 0.89875248
# CSD25_full 0.7706510697674419
# CSD25_interface 0.9635504772691544
# CSD25_neighborhood 0.9087039069767443
# CSD26_full 0.7220324008714597
# CSD26_interface 0.9368524362507892
# CSD26_neighborhood 0.8593178474945534

# %% [markdown]
# Very interesting, so compared to the design model, the MPNN designs have lower similarity than among themselves!
# Makes sense- likely there are some positions in the structure which MPNN usually mutates to the same different residue ID. In other words, there are some specific mutations from the original design which MPNN favors.

# %%
# extract Y states from all the unique sequences

sbatch_fname = 'split_Y_designs'

from more_itertools import chunked

unique_paths = []
for length, seq_path in len_seq_path.items():
    unique_paths += list(seq_path.values())

task_lines = []
for path_chunk in chunked(unique_paths, 100):
    task_lines.append(f"/home/broerman/projects/CSD/round_2/mpnn/{sbatch_fname}.py {' '.join(path_chunk)}\n")

with open(f'{sbatch_fname}.tasks', 'w') as tasks_file:
    tasks_file.write(''.join(task_lines))

print(f'sbatch -a 1-$(cat {sbatch_fname}.tasks | wc -l) {sbatch_fname}.sh')

sbatch_script = \
f"""#!/usr/bin/env bash 
#SBATCH -J {sbatch_fname}
#SBATCH -e /mnt/home/broerman/projects/CSD/slurm_logs/{sbatch_fname}-%J.err 
#SBATCH -o /mnt/home/broerman/projects/CSD/slurm_logs/{sbatch_fname}-%J.out 
#SBATCH -p short
#SBATCH -c 1
#SBATCH --mem=1536M

JOB_ID=${{SLURM_JOB_ID%;*}}
CMD=$(sed -n "${{SLURM_ARRAY_TASK_ID}}p" /home/broerman/projects/CSD/round_2/mpnn/{sbatch_fname}.tasks) 
echo "${{CMD}}" | bash
"""

with open(f'{sbatch_fname}.sh', 'w') as sh_file:
    sh_file.write(sbatch_script)
# Out:
# sbatch -a 1-$(cat split_Y_designs.tasks | wc -l) split_Y_designs.sh

# %%
# alphafold
# bins proteins with the same total length in one prediction
# this should prevent the model from needing to be rebuilt for different lengths, while still allowing me to split the jobs across different nodes
# further chunks for more parallelization

from more_itertools import chunked

task_lines = []

for length, seq_path in len_seq_path.items():
    for file_chunk in chunked(seq_path.values(), 230):
        file_str = ' '.join(reversed([x[:-4].replace('mpnn_designs', 'unique_mpnn_Y_designs') + '_AB_Y.pdb' for x in file_chunk]))
        task_lines.append(f"/home/rdkibler/software/superfold/superfold {file_str} --simple_rmsd --initial_guess --models all --max_recycles 4 --out_dir /home/broerman/projects/CSD/round_2/mpnn/unique_mpnn_Y_af2\n")

task_lines.reverse()

sbatch_fname = 'af2_mpnn_Y_designs'

with open(f'{sbatch_fname}.tasks', 'w') as tasks_file:
    tasks_file.write(''.join(task_lines))

print(f'sbatch -a 1-$(cat {sbatch_fname}.tasks | wc -l) {sbatch_fname}.sh')

sbatch_script = \
f"""#!/usr/bin/env bash 
#SBATCH -J {sbatch_fname}
#SBATCH -e /home/broerman/projects/CSD/slurm_logs/{sbatch_fname}-%J.err 
#SBATCH -o /home/broerman/projects/CSD/slurm_logs/{sbatch_fname}-%J.out 
#SBATCH -p gpu
#SBATCH -c 2
#SBATCH --mem=6G
#SBATCH --gres=gpu:rtx2080ti:1

JOB_ID=${{SLURM_JOB_ID%;*}}
CMD=$(sed -n "${{SLURM_ARRAY_TASK_ID}}p" /home/broerman/projects/CSD/round_2/mpnn/{sbatch_fname}.tasks) 
echo "${{CMD}}" | bash
"""

with open(f'{sbatch_fname}.sh', 'w') as sh_file:
    sh_file.write(sbatch_script)
# Out:
# sbatch -a 1-$(cat af2_mpnn_Y_designs.tasks | wc -l) af2_mpnn_Y_designs.sh

# %%
from glob import glob
with open('unique_mpnn_Y_af2_scores.json', 'w') as score_file:
    score_file.write('{')
    for ind_score_path in sorted(glob('unique_mpnn_Y_af2/*.json')):
        ind_score_path_split = ind_score_path.split('/')
        name = ind_score_path_split[-1][:-24]
        with open(ind_score_path, 'r') as ind_score_file:
            contents = ind_score_file.read()
            content_end = contents.find('}')
            contents = '"' + name + '":' + contents[:content_end+1].replace(' ', '').replace('\n', '') + ',\n'
            score_file.write(contents)
    score_file.write('}')

# %%
import pandas as pd
scores_df = pd.read_json('unique_mpnn_Y_af2_scores.json', orient='index')

from IPython.display import display
with pd.option_context(
    'display.max_columns', None,
    # 'display.max_rows', None,
):
    display(scores_df)
# Out:
#                                                   mean_plddt  recycles  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0           96.629387         4
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0           95.309937         4
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0           96.268456         4
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0           95.628143         4
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0           97.187355         4
# ...                                                      ...       ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0   94.885956         4
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0   94.256180         4
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0   95.137260         4
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0   93.683464         4
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0   95.654709         4
#
#                                                        tol  model  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0          3.010552      1
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0          0.967259      2
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0          0.964093      3
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0          0.312819      4
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0          1.235245      5
# ...                                                    ...    ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0  1.558376      1
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0  0.916652      2
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0  0.749453      3
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0  0.889115      4
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0  1.089096      5
#
#                                                          type  seed  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0          monomer_ptm     0
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0          monomer_ptm     0
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0          monomer_ptm     0
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0          monomer_ptm     0
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0          monomer_ptm     0
# ...                                                       ...   ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0  monomer_ptm     0
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0  monomer_ptm     0
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0  monomer_ptm     0
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0  monomer_ptm     0
#
#                                                   rmsd_to_input  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0               9.134451
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0              10.777146
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0               8.488046
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0               8.457017
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0              17.227060
# ...                                                         ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0      16.369131
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0      16.830259
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0      15.664867
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0       9.428436
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0      21.332790
#
#                                                   mean_pae_interaction_AB  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0                        26.012844
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0                        28.312353
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0                        28.245234
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0                        28.174196
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0                        27.383789
# ...                                                                   ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0                27.057514
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0                28.000776
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0                28.194609
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0                28.892342
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0                27.415451
#
#                                                   mean_pae_interaction_BA  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0                        25.557861
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0                        27.748766
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0                        27.663065
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0                        27.651560
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0                        26.677704
# ...                                                                   ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0                26.874079
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0                27.849710
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0                27.990736
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0                28.987549
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0                27.200092
#
#                                                   mean_pae_interaction  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0                     25.785353
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0                     28.030560
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0                     27.954149
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0                     27.912878
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0                     27.030746
# ...                                                                ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0             26.965797
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0             27.925243
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0             28.092672
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0             28.939945
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0             27.307772
#
#                                                   mean_pae_intra_chain_A  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0                        2.664663
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0                        2.846421
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0                        2.740602
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0                        2.726438
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0                        2.428382
# ...                                                                  ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0                3.974677
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0                4.056689
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0                3.800986
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0                4.163044
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0                3.319466
#
#                                                   mean_pae_intra_chain_B  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0                        2.257559
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0                        2.215160
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0                        2.197530
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0                        2.240301
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0                        2.023293
# ...                                                                  ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0                2.932053
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0                2.899046
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0                2.989531
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0                3.151018
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0                2.791129
#
#                                                   mean_pae_intra_chain  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0                      2.461111
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0                      2.530790
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0                      2.469066
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0                      2.483370
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0                      2.225838
# ...                                                                ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0              3.453365
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0              3.477868
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0              3.395259
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0              3.657031
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0              3.055297
#
#                                                    mean_pae  pTMscore  \
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0          14.128551  0.538078
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0          15.285163  0.511665
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0          15.220641  0.518718
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0          15.205062  0.517583
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0          14.634046  0.523255
# ...                                                     ...       ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0  15.227156  0.532856
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0  15.723059  0.515102
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0  15.766117  0.513662
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0  16.317663  0.503717
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0  15.195518  0.519521
#
#                                                   elapsed_time
# CSD20_111_full_0_AB_Y_model_1_ptm_seed_0            244.142474
# CSD20_111_full_0_AB_Y_model_2_ptm_seed_0             56.841699
# CSD20_111_full_0_AB_Y_model_3_ptm_seed_0             57.238011
# CSD20_111_full_0_AB_Y_model_4_ptm_seed_0             57.447873
# CSD20_111_full_0_AB_Y_model_5_ptm_seed_0             57.217913
# ...                                                        ...
# CSD26_553_neighborhood_9_AB_Y_model_1_ptm_seed_0    396.609676
# CSD26_553_neighborhood_9_AB_Y_model_2_ptm_seed_0     91.727224
# CSD26_553_neighborhood_9_AB_Y_model_3_ptm_seed_0     91.581882
# CSD26_553_neighborhood_9_AB_Y_model_4_ptm_seed_0     91.800364
# CSD26_553_neighborhood_9_AB_Y_model_5_ptm_seed_0     91.599728
#
# [20415 rows x 16 columns]

# %%
import sys
sys.path.insert(0, '/home/broerman/projects/crispy_shifty/')
from crispy_shifty.utils.plotting import histplot_df

cols = [
        "mean_plddt",
        "rmsd_to_input",
        "tol",
        "pTMscore",
        "mean_pae_interaction",
        "mean_pae"
    ]

# make sure all the columns to plot are numeric
fig, axs = histplot_df(scores_df, cols=cols)
# Out:
# 6it [00:00,  7.55it/s]

# %%
def filter_df(df, cutoffs):
    filtered_df = df

    for score_term, cutoff, greaterthan in cutoffs:
        if greaterthan:
            filtered_df = filtered_df[filtered_df[score_term] > cutoff]
        else:
            filtered_df = filtered_df[filtered_df[score_term] < cutoff]

    print(len(filtered_df))
    
    return filtered_df

# %%
# Filter designs

cutoffs = [
    # ('mean_plddt', 85, 1),
    ('rmsd_to_input', 3, 0),
    # ('tol', 1, 0)
]

filtered_df = filter_df(scores_df, cutoffs)
filtered_df
# Out:
# 31
#                                                   mean_plddt  recycles  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0      95.798759         4
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0      94.397652         4
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0      95.070877         4
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0   93.257431         4
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0   93.230423         4
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0   94.291054         4
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0   93.392342         4
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0      92.414238         4
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0      93.720459         4
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0   92.413521         4
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0   92.524704         4
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0   93.926918         4
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0   93.241211         4
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0   93.031326         4
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0   94.572968         4
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0   93.714561         4
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0   94.255783         4
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0           95.255730         4
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0      94.242096         4
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0      93.171417         4
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0   92.259422         4
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0           94.722710         4
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0      94.499008         4
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0      94.504684         4
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0      94.384438         4
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0      93.973793         4
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0   93.988594         4
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0   94.166145         4
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0   93.590446         4
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0      93.766777         4
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0      91.960251         4
#
#                                                        tol  model  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0     0.079333      2
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0     0.113534      3
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0     0.071950      1
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0  0.055695      1
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0  0.056352      1
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0  0.138648      1
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0  0.066015      1
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0     0.100591      1
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0     0.240775      1
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0  0.093827      1
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0  0.111231      1
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0  0.076647      1
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0  0.102920      2
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0  0.105136      2
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0  0.068459      1
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0  0.118160      1
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0  0.101251      1
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0          0.085860      1
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0     0.076634      1
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0     0.086527      1
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0  0.163519      2
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0          0.420018      1
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0     0.071052      1
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0     0.060519      1
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0     0.063977      1
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0     0.079967      1
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0  0.105646      1
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0  0.187417      1
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0  0.169364      1
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0     0.076216      1
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0     0.204179      1
#
#                                                          type  seed  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0     monomer_ptm     0
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0     monomer_ptm     0
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0          monomer_ptm     0
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0  monomer_ptm     0
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0          monomer_ptm     0
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0  monomer_ptm     0
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0     monomer_ptm     0
#
#                                                   rmsd_to_input  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0          0.414059
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0          0.735123
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0          0.672192
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0       0.896960
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0       0.718645
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0       0.880679
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0       0.859160
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0          0.595698
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0          0.555640
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0       1.151547
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0       0.903131
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0       0.798774
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0       1.118456
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0       1.009787
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0       0.860146
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0       1.012509
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0       0.925274
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0               1.230215
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0          0.915080
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0          0.916955
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0       1.438396
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0               2.311192
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0          0.883180
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0          1.220625
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0          1.225494
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0          1.060935
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0       0.827581
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0       1.554743
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0       1.240915
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0          0.807873
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0          1.165425
#
#                                                   mean_pae_interaction_AB  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0                    3.656541
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0                    4.330067
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0                    4.024634
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0                 4.707980
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0                 5.283978
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0                 4.608759
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0                 5.052388
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0                    6.140304
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0                    7.422854
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0                 6.463163
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0                 7.010704
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0                 5.691300
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0                 5.922556
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0                 5.507982
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0                 5.238991
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0                 5.895082
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0                 5.348628
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0                         4.897458
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0                    5.039596
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0                    6.014715
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0                 5.722074
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0                         7.390617
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0                    4.951517
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0                    5.265539
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0                    5.240443
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0                    5.641044
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0                 7.254817
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0                 8.515258
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0                 6.747517
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0                    5.946095
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0                    7.700006
#
#                                                   mean_pae_interaction_BA  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0                    3.597531
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0                    4.661396
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0                    3.892107
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0                 5.128904
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0                 5.219514
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0                 4.578870
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0                 5.049619
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0                    5.898117
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0                    7.072772
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0                 6.374064
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0                 6.903460
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0                 5.431375
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0                 5.547159
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0                 5.142199
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0                 4.945470
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0                 5.568194
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0                 5.129562
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0                         4.700572
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0                    4.869782
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0                    5.781023
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0                 5.572584
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0                         6.518372
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0                    4.691317
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0                    4.957251
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0                    4.983784
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0                    5.416297
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0                 6.552470
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0                 7.794790
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0                 6.257155
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0                    5.635999
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0                    6.999561
#
#                                                   mean_pae_interaction  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0                 3.627036
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0                 4.495731
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0                 3.958370
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0              4.918442
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0              5.251746
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0              4.593815
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0              5.051003
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0                 6.019211
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0                 7.247813
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0              6.418613
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0              6.957082
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0              5.561337
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0              5.734858
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0              5.325090
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0              5.092231
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0              5.731638
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0              5.239095
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0                      4.799015
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0                 4.954689
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0                 5.897869
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0              5.647329
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0                      6.954494
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0                 4.821417
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0                 5.111395
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0                 5.112113
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0                 5.528670
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0              6.903644
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0              8.155024
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0              6.502337
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0                 5.791047
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0                 7.349783
#
#                                                   mean_pae_intra_chain_A  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0                   2.611556
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0                   2.749171
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0                   2.859179
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0                3.533282
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0                4.182727
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0                3.569273
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0                3.789704
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0                   4.864158
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0                   6.527853
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0                5.182376
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0                5.545737
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0                4.921759
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0                4.957938
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0                4.434028
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0                4.347089
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0                5.059395
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0                4.395869
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0                        4.273579
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0                   3.987738
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0                   4.865877
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0                4.299705
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0                        6.347807
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0                   3.989424
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0                   4.310827
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0                   4.285302
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0                   4.657099
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0                6.308432
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0                7.490778
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0                5.701432
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0                   5.254128
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0                   6.199288
#
#                                                   mean_pae_intra_chain_B  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0                   2.582283
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0                   3.207245
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0                   2.718926
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0                3.768774
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0                3.411818
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0                3.198790
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0                3.433265
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0                   3.574503
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0                   3.043585
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0                3.455705
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0                3.455262
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0                3.096731
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0                3.072687
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0                3.153701
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0                2.951335
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0                2.975009
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0                3.068405
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0                        2.833059
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0                   3.197906
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0                   3.352923
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0                3.718114
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0                        2.645488
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0                   3.044633
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0                   2.961133
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0                   3.005560
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0                   3.089965
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0                2.947474
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0                2.768831
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0                2.943169
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0                   3.034510
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0                   3.522688
#
#                                                   mean_pae_intra_chain  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0                 2.596920
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0                 2.978208
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0                 2.789052
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0              3.651028
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0              3.797273
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0              3.384032
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0              3.611485
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0                 4.219331
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0                 4.785719
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0              4.319040
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0              4.500500
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0              4.009245
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0              4.015313
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0              3.793864
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0              3.649212
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0              4.017202
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0              3.732137
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0                      3.553319
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0                 3.592822
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0                 4.109400
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0              4.008909
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0                      4.496647
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0                 3.517029
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0                 3.635980
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0                 3.645431
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0                 3.873532
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0              4.627954
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0              5.129805
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0              4.322300
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0                 4.144319
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0                 4.860989
#
#                                                   mean_pae  pTMscore  \
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0     3.165269  0.929809
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0     3.788677  0.912833
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0     3.429926  0.917810
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0  4.344973  0.908040
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0  4.586757  0.895096
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0  4.047790  0.911572
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0  4.394326  0.902036
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0     5.169480  0.871291
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0     6.065533  0.865589
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0  5.407731  0.844581
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0  5.778351  0.843564
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0  4.834922  0.887434
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0  4.922956  0.879548
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0  4.603266  0.880797
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0  4.423284  0.900098
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0  4.924338  0.881389
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0  4.534700  0.895167
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0          4.213152  0.889608
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0     4.324455  0.898355
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0     5.053540  0.876889
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0  4.874847  0.866655
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0          5.743155  0.856180
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0     4.220678  0.907493
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0     4.424618  0.901716
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0     4.429680  0.897680
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0     4.751009  0.886655
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0  5.808340  0.866701
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0  6.685256  0.843198
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0  5.455988  0.872431
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0     5.017692  0.882398
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0     6.153232  0.841986
#
#                                                   elapsed_time
# CSD20_151_interface_9_AB_Y_model_2_ptm_seed_0        57.152646
# CSD20_351_interface_1_AB_Y_model_3_ptm_seed_0        56.779284
# CSD20_351_interface_6_AB_Y_model_1_ptm_seed_0        58.216789
# CSD25_131_neighborhood_4_AB_Y_model_1_ptm_seed_0     62.911491
# CSD25_311_neighborhood_6_AB_Y_model_1_ptm_seed_0     63.228890
# CSD25_411_neighborhood_5_AB_Y_model_1_ptm_seed_0     64.065257
# CSD25_411_neighborhood_8_AB_Y_model_1_ptm_seed_0     63.898478
# CSD26_153_interface_0_AB_Y_model_1_ptm_seed_0        91.034792
# CSD26_212_interface_5_AB_Y_model_1_ptm_seed_0        93.136534
# CSD26_231_neighborhood_0_AB_Y_model_1_ptm_seed_0     91.651255
# CSD26_231_neighborhood_1_AB_Y_model_1_ptm_seed_0     91.303304
# CSD26_231_neighborhood_2_AB_Y_model_1_ptm_seed_0     91.028923
# CSD26_231_neighborhood_3_AB_Y_model_2_ptm_seed_0     89.005231
# CSD26_231_neighborhood_5_AB_Y_model_2_ptm_seed_0     89.123832
# CSD26_231_neighborhood_6_AB_Y_model_1_ptm_seed_0     91.144149
# CSD26_231_neighborhood_8_AB_Y_model_1_ptm_seed_0     90.667037
# CSD26_231_neighborhood_9_AB_Y_model_1_ptm_seed_0     90.462628
# CSD26_232_full_5_AB_Y_model_1_ptm_seed_0             90.527646
# CSD26_232_interface_0_AB_Y_model_1_ptm_seed_0        90.847392
# CSD26_232_interface_5_AB_Y_model_1_ptm_seed_0        89.787377
# CSD26_233_neighborhood_5_AB_Y_model_2_ptm_seed_0     70.993056
# CSD26_241_full_7_AB_Y_model_1_ptm_seed_0             72.442599
# CSD26_242_interface_1_AB_Y_model_1_ptm_seed_0        72.892168
# CSD26_252_interface_0_AB_Y_model_1_ptm_seed_0        72.114881
# CSD26_252_interface_1_AB_Y_model_1_ptm_seed_0        72.714095
# CSD26_252_interface_4_AB_Y_model_1_ptm_seed_0        71.951983
# CSD26_331_neighborhood_3_AB_Y_model_1_ptm_seed_0     71.929157
# CSD26_331_neighborhood_4_AB_Y_model_1_ptm_seed_0     72.297288
# CSD26_331_neighborhood_5_AB_Y_model_1_ptm_seed_0     72.113931
# CSD26_332_interface_5_AB_Y_model_1_ptm_seed_0        72.329826
# CSD26_541_interface_1_AB_Y_model_1_ptm_seed_0        95.362181

# %%
fig, axs = histplot_df(filtered_df, cols=cols)
# Out:
# 6it [00:00, 42.98it/s]

# %%
# copy designs

import shutil

for index in filtered_df.index:
    af2_fname = 'unique_mpnn_Y_af2/' + index + '_unrelaxed.pdb'
    shutil.copy(af2_fname, 'selected_designs/')

# %%
# add sequences to df

from Bio import SeqIO
from IPython.utils.io import capture_output

for index in filtered_df.index:
    af2_fname = 'unique_mpnn_Y_af2/' + index + '_unrelaxed.pdb'
    sequence = ''
    with capture_output() as captured: # otherwise memory overloads lol
        for i, record in enumerate(SeqIO.parse(af2_fname, 'pdb-atom')):
            sequence += str(record.seq)
    filtered_df.at[index, 'sequence'] = sequence
# Out:
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# look at distribution of percent sequence identity of each design to the original, as well as the sequence diversity of all designs
from collections import defaultdict

# bin seqs by parent backbone and extent of redesign

all_seqs_designs = {}
binned_sequences = defaultdict(list)

for index, row in filtered_df.iterrows():
    sequence = row['sequence']
    index_split = index.split('_')
    design_id = index_split[0] + '_' + index_split[2]
    binned_sequences[design_id].append(sequence)

# %%
from Bio import SeqIO
from glob import glob
from IPython.utils.io import capture_output

len_seq_path = defaultdict(dict)

orig_seqs = {}

for design_id in binned_sequences.keys():
    file_path = glob('/home/broerman/projects/CSD/round_2/mpnn/backbone_combos/' + design_id.split('_')[0] + '*.pdb')[0]
    sequence = ''
    with capture_output() as captured: # otherwise memory overloads lol
        for i, record in enumerate(SeqIO.parse(file_path, 'pdb-atom')):
            if i < 2:
                sequence += str(record.seq)
            else:
                break
    orig_seqs[design_id] = sequence

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 3, figsize=(9, 6))

for (design_id, seqs), ax in zip(binned_sequences.items(), axs.flatten()):
    orig_seq = orig_seqs[design_id]
    seq_len = len(orig_seq)
    similarities = []
    for seq in seqs:
        similarities.append(sum([seq[i] == orig_seq[i] for i in range(seq_len)]) / seq_len)

    ax.hist(similarities)
    ax.set_title(design_id)
    
fig.tight_layout()

# %%
# how do you come up with a number for the sequence diversity of all designs against each other?
# for each design, compute its sequence diversity against all other designs, average them, then average all these averages

# could find a smarter way to do this with matrix multiplication, but ehh

import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 3, figsize=(9,6))

for (design_id, seqs), ax in zip(binned_sequences.items(), axs.flatten()):
    mean_similarities = []
    for base_seq in seqs:
        seq_len = len(base_seq)
        mean_similarity = np.mean([np.sum([seq[i] == base_seq[i] for i in range(seq_len)]) / seq_len for seq in seqs])
        mean_similarities.append(mean_similarity)
    ax.hist(mean_similarities)
    ax.set_title(design_id)
    print(design_id, np.mean(mean_similarities))

fig.tight_layout()
# Out:
# CSD20_interface 0.9613821138211383
# CSD25_neighborhood 0.9295058139534884
# CSD26_interface 0.9468137254901962
# CSD26_neighborhood 0.9071010348583878
# CSD26_full 0.8443627450980392
