# %% [markdown]
# # Do interface design to further filter out unproductive designs prior to looping

# %%
# %load_ext lab_black
# Python standard library
from glob import glob
import os
import socket
import sys

# 3rd party library imports
import dask
import matplotlib.pyplot as plt
import pandas as pd
import pyrosetta
import numpy as np
import scipy
import seaborn as sns
from tqdm.auto import tqdm  # jupyter compatible progress bar

tqdm.pandas()  # link tqdm to pandas
# Notebook magic
# save plots in the notebook
# %matplotlib inline
# reloads modules automatically before executing cells
# %load_ext autoreload
# %autoreload 2
print(f"running in directory: {os.getcwd()}")  # where are we?
print(f"running on node: {socket.gethostname()}")  # what node are we on?
# Out:
# running in directory: /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers
# running on node: jojo

# %%
sns.set(
    context="talk",
    # font_scale=1,  # make the font larger; default is pretty small
    style="ticks",  # make the background white with black lines
    palette="colorblind",  # a color palette that is colorblind friendly!
)

# %%
os.chdir("/home/broerman/projects/crispy_shifty")
sys.path.insert(0, os.getcwd())

# %%
def create_tasks(selected, options):
    with open(selected, "r") as f:
        for line in f:
            tasks = {"options": "-corrections::beta_nov16 true"}
            tasks["extra_options"] = options
            tasks["pdb_path"] = line.rstrip()
            yield tasks

# %%
os.chdir("/home/broerman/projects/crispy_shifty")
# Python standard library
import os
import pwd
import socket
import sys

# 3rd party library imports
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# Rosetta library imports
from pyrosetta.distributed.cluster.core import PyRosettaCluster

# Custom library imports
sys.path.insert(0, os.getcwd())
from crispy_shifty.protocols.design import one_state_design_unlooped_dimer  # the functions we will distribute

print(f"View dashboard at http://{socket.gethostname()}:8787")

selected = os.path.join(os.getcwd(), "projects/crispy_shifty_dimers/01_make_states/states.list")

options = {
    "-out:level": "100",
    "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
    "-indexed_structure_store:fragment_store": "/net/databases/VALL_clustered/connect_chains/ss_grouped_vall_helix_shortLoop.h5",
    "-precompute_ig": "true"
}

output_path = os.path.join(os.getcwd(), "projects/crispy_shifty_dimers/02_design_filter")
os.makedirs(output_path, exist_ok=True)

if __name__ == "__main__":
    # configure SLURM cluster as a context manager
    with SLURMCluster(
        cores=1,
        processes=1,
        job_cpu=1,
        memory="10GB",
        queue="backfill",
        walltime="11:30:00",
        death_timeout=120,
        local_directory="$TMPDIR",  # spill worker litter on local node temp storage
        log_directory=os.path.join(output_path, "slurm_logs"),
        extra=["--lifetime", "11h", "--lifetime-stagger", "5m"],
    ) as cluster:
        print(cluster.job_script())
        # scale between 1-300 workers,
        cluster.adapt(
            minimum=1,
            maximum=300,
            wait_count=999,  # Number of consecutive times that a worker should be suggested for removal it is removed
            interval="5s",  # Time between checks
            target_duration="60s",
        )
        # setup a client to interact with the cluster as a context manager
        with Client(cluster) as client:
            print(client)
            client.upload_file(
                os.path.join(os.getcwd(), "crispy_shifty/protocols/design.py")
            )  # upload the script that contains the functions to distribute
            PyRosettaCluster(
                client=client,
                logging_level="ERROR",
                output_path=output_path,
                project_name="crispy_shifty_dimers",
                scratch_dir=output_path,
                simulation_name="02_design_filter",
                tasks=create_tasks(selected, options),
                nstruct=10,
            ).distribute(protocols=[one_state_design_unlooped_dimer])
            client.close()
        cluster.scale(0)
        cluster.close()
    print("distributed run complete")
# Out:
# View dashboard at http://dig62:8787
# #!/usr/bin/env bash
#
# #SBATCH -J dask-worker
# #SBATCH -e /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter/slurm_logs/dask-worker-%J.err
# #SBATCH -o /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter/slurm_logs/dask-worker-%J.out
# #SBATCH -p medium
# #SBATCH -n 1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem=12G
# #SBATCH -t 23:30:00
#
# /projects/crispy_shifty/envs/crispy/bin/python -m distributed.cli.dask_worker tcp://172.16.131.92:34317 --nthreads 1 --memory-limit 11.18GiB --name dummy-name --nanny --death-timeout 120 --local-directory $TMPDIR --lifetime 23h --lifetime-stagger 5m --protocol tcp://
#
# <Client: 'tcp://172.16.131.92:34317' processes=0 threads=0, memory=0 B>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_157753/2100797226.py in <module>
#      59                 os.path.join(os.getcwd(), "crispy_shifty/protocols/design.py")
#      60             )  # upload the script that contains the functions to distribute
# ---> 61             PyRosettaCluster(
#      62                 client=client,
#      63                 logging_level="WARNING",
#
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/pyrosetta/distributed/cluster/core.py in distribute(self, protocols, *args)
#     603             ]
#     604         )
# --> 605         for i, future in enumerate(seq, start=1):
#     606             try:
#     607                 results = future.result()
#
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/client.py in __next__(self)
#    4526                 raise StopIteration()
#    4527             with self.thread_condition:
# -> 4528                 self.thread_condition.wait(timeout=0.100)
#    4529         return self._get_and_raise()
#    4530
#
# /projects/crispy_shifty/envs/crispy/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
def read_scorefile(scores):
    import pandas as pd

    scores = pd.read_json(scores, orient="records", typ="frame", lines=True)
    scores = scores.T
    mat = scores.values
    n = mat.shape[0]
    dicts = list(mat[range(n), range(n)])
    index = scores.index
    tabulated_scores = pd.DataFrame(dicts, index=index)
    return tabulated_scores

os.chdir("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers")
output_path = os.path.join(os.getcwd(), "02_design_filter")
scores = os.path.join(output_path, "scores.json")
scores_df = read_scorefile(scores)
scores_df.head()
# Out:
#                                                               bb_clash  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  110.83558654785156
# /mnt/home/broerman/projects/crispy_shifty/proje...           4650.0625
# /mnt/home/broerman/projects/crispy_shifty/proje...      4802.529296875
# /mnt/home/broerman/projects/crispy_shifty/proje...  103.79744720458984
# /mnt/home/broerman/projects/crispy_shifty/proje...   2832.929931640625
#
#                                                             bb_clash_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   56.11193084716797
# /mnt/home/broerman/projects/crispy_shifty/proje...  41.235984802246094
# /mnt/home/broerman/projects/crispy_shifty/proje...  37.104209899902344
# /mnt/home/broerman/projects/crispy_shifty/proje...   69.95219421386719
# /mnt/home/broerman/projects/crispy_shifty/proje...  37.104209899902344
#
#                                                             bb_clash_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   54.72365951538086
# /mnt/home/broerman/projects/crispy_shifty/proje...  41.235984802246094
# /mnt/home/broerman/projects/crispy_shifty/proje...     613.51220703125
# /mnt/home/broerman/projects/crispy_shifty/proje...  33.758880615234375
# /mnt/home/broerman/projects/crispy_shifty/proje...    2794.31787109375
#
#                                                     cms_ac_bn     cms_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  368.517517
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  245.856781
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  152.555206
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.121686  322.327301
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  128.971451
#
#                                                     cms_dhr_ac  cms_dhr_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  514.184814  637.900879
# /mnt/home/broerman/projects/crispy_shifty/proje...  320.443359    0.000000
# /mnt/home/broerman/projects/crispy_shifty/proje...  324.429718  314.094727
# /mnt/home/broerman/projects/crispy_shifty/proje...  384.285004  297.629730
# /mnt/home/broerman/projects/crispy_shifty/proje...  296.732544  126.221008
#
#                                                    dhr_ac_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             26.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             12.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             15.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             20.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             15.0
#
#                                                    dhr_bn_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             35.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             37.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             31.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             10.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             24.0
#
#                                                    dhr_int_count  ... shift_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          19.0  ...    -6.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          15.0  ...     1.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          14.0  ...     5.0
# /mnt/home/broerman/projects/crispy_shifty/proje...           5.0  ...     5.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          14.0  ...     5.0
#
#                                                    shift_B     ss_sc  \
# /mnt/home/broerman/projects/crispy_shifty/proje...     6.0  0.713926
# /mnt/home/broerman/projects/crispy_shifty/proje...    -1.0  0.733583
# /mnt/home/broerman/projects/crispy_shifty/proje...     3.0  0.720846
# /mnt/home/broerman/projects/crispy_shifty/proje...    -1.0  0.725128
# /mnt/home/broerman/projects/crispy_shifty/proje...     2.0  0.703402
#
#                                                            total_score  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   41261.58817176744
# /mnt/home/broerman/projects/crispy_shifty/proje...  22383.564461821425
# /mnt/home/broerman/projects/crispy_shifty/proje...  30201.420730267128
# /mnt/home/broerman/projects/crispy_shifty/proje...  20943.983241058155
# /mnt/home/broerman/projects/crispy_shifty/proje...  22138.093955425633
#
#                                                        wnm_1     wnm_2  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.354899  0.397061
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.363062  0.459005
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.281702  0.284034
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.256686  0.225569
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.286762  0.299825
#
#                                                        wnm_3     wnm_4  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.329438  0.365875
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.373733  0.435767
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.373289  0.349887
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.257751  0.200958
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.254358  0.303265
#
#                                                      wnm_hlx  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.129802
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.089698
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.115567
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.108887
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.104817
#
#                                                             yhh_planarity
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.0015607019201311911
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.0015607019201311911
#
# [5 rows x 61 columns]

# %%
print(scores_df.columns)
print(len(scores_df))
# Out:
# Index(['bb_clash', 'bb_clash_A', 'bb_clash_B', 'cms_ac_bn', 'cms_dhr',
#        'cms_dhr_ac', 'cms_dhr_bn', 'dhr_ac_int_count', 'dhr_bn_int_count',
#        'dhr_int_count', 'dslf_fa13', 'fa_atr', 'fa_dun', 'fa_elec',
#        'fa_intra_rep', 'fa_intra_sol_xover4', 'fa_rep', 'fa_sol',
#        'hbond_bb_sc', 'hbond_lr_bb', 'hbond_sc', 'hbond_sr_bb', 'lk_ball_wtd',
#        'loop_dist_A', 'loop_dist_B', 'omega', 'p_aa_pp', 'parent',
#        'parent_length', 'parent_loop_dist', 'parent_path', 'pivot_helix_A',
#        'pivot_helix_B', 'pre_break_helix', 'pro_close', 'rama_prepro', 'ref',
#        'sc_ac_bn', 'sc_dhr', 'sc_dhr_ac', 'sc_dhr_bn', 'score', 'score_1',
#        'score_124', 'score_134', 'score_14', 'score_2', 'score_23', 'score_3',
#        'score_4', 'score_per_res', 'shift_A', 'shift_B', 'ss_sc',
#        'total_score', 'wnm_1', 'wnm_2', 'wnm_3', 'wnm_4', 'wnm_hlx',
#        'yhh_planarity'],
#       dtype='object')
# 12993

# %%
# Add the input path to the dataframe
import pyrosetta.distributed.cluster as cluster
for index, row in tqdm(scores_df.iterrows()):
    input_path = cluster.get_scores_dict(index)['instance']['tasks']['pdb_path']
    scores_df.at[index, 'input_path'] = input_path
# Out:
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# 12993it [03:09, 68.72it/s]

# %%
scores_df['input_path'].nunique()
# Out:
# 2557

# %%
input_path_dict = {}
for input_path in tqdm(scores_df['input_path']):
    if input_path in input_path_dict:
        input_path_dict[input_path] += 1
    else:
        input_path_dict[input_path] = 1

sns.histplot(input_path_dict.values(), discrete=True)
# Out:
# 100%|██████████| 12993/12993 [00:00<00:00, 1515941.80it/s]
# <AxesSubplot:ylabel='Count'>

# %%
scores_df['parent'].nunique()
# Out:
# 213

# %%
# Compute derivative scores, then check whether there is significant variation among scores for designs from the same input

scores_df['de_1_4'] = scores_df['score_14'] - scores_df['score_1'] - scores_df['score_4']
scores_df['de_14_2'] = scores_df['score_124'] - scores_df['score_14'] - scores_df['score_2']
scores_df['de_14_3'] = scores_df['score_134'] - scores_df['score_14'] - scores_df['score_3']
scores_df['de_2_3'] = scores_df['score_23'] - scores_df['score_2'] - scores_df['score_3']
scores_df['wnm'] = scores_df[['wnm_1', 'wnm_2', 'wnm_3', 'wnm_4']].max(axis=1)
scores_df['delta_loop_dist_A'] = scores_df['loop_dist_A'].astype(float) - scores_df['parent_loop_dist'].astype(float)
scores_df['delta_loop_dist_B'] = scores_df['loop_dist_B'].astype(float) - scores_df['parent_loop_dist'].astype(float)

# %%
sys.path.insert(0, "/home/broerman/projects/crispy_shifty")
from crispy_shifty.plotting.utils import histplot_df

cols = [
        "cms_dhr",
        "cms_dhr_ac",
        "cms_dhr_bn",
        "cms_ac_bn",
        "de_1_4",
        "de_14_2",
        "de_14_3",
        "de_2_3",
        "score_per_res",
        "delta_loop_dist_A",
        "delta_loop_dist_B",
        "wnm",
        "wnm_1",
        "wnm_2",
        "wnm_3",
        "wnm_4",
        "wnm_hlx",
        "ss_sc",
        "sc_dhr",
        "sc_dhr_ac",
        "sc_dhr_bn",
        "sc_ac_bn"
    #     "parent",
    ]

histplot_df(scores_df, cols=cols, bins=100)
# Out:
# 22it [00:01, 11.62it/s]

# %%
# Look at the distributions of scores for each input- see if there is significant variation, indicating I need to sample more, or if I
# only need to sample a few design trajectories for each design.
# Let's look at the ~50 inputs for which I sampled 15 trajectories, so I have some more data.

input_paths_15 = []
for input_path, num_occurrences in input_path_dict.items():
    if num_occurrences == 15:
        input_paths_15.append(input_path)
num_input_15 = len(input_paths_15)
print(num_input_15)

inputs_cols = [
        "cms_dhr",
        "cms_dhr_ac",
        "cms_dhr_bn",
        "score_per_res",
        "wnm",
        "wnm_hlx",
        "ss_sc",
        "sc_dhr",
        "sc_dhr_ac",
        "sc_dhr_bn",
    ]
num_cols = len(inputs_cols)

fig, axs = plt.subplots(num_input_15, num_cols, figsize=(4*num_cols, 4*num_input_15))

std_mean_df = pd.DataFrame(index=input_paths_15, columns=inputs_cols)

for i, input_path in tqdm(enumerate(input_paths_15)):
    scores_df_input = scores_df[scores_df['input_path'] == input_path]
    
    for j, col in enumerate(inputs_cols):
        sns.histplot(data=scores_df_input, x=col, ax=axs[i,j], bins=5)
    
    std_mean_df.loc[input_path, :] = scores_df_input[inputs_cols].std(axis=0) / scores_df_input[inputs_cols].mean(axis=0)

fig.tight_layout()
# Out:
# 51
# 51it [00:10,  4.68it/s]

# %%
# Plots distributions of the standard deviations of the scores normalized by the mean of those scores for each input.
# For each metric, values around ~0.05 for sc, 0.1 for cms indicate I need to sample highly per design, maybe ~10 trajectories, to make
# full use of each design for optimizing that metric.

histplot_df(std_mean_df, cols=inputs_cols)

# %%
# This means I need to sample more for the inputs which only had a few or no corresponding designs. Generate a list of inputs with less than 5 designs
# and sample with nstruct 5.

input_scores_df = read_scorefile("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/01_make_states/scores.json")

# get the paths to the inputs for which I have no designs
input_paths_to_sample = []
for input_path in input_scores_df.index:
    if input_path not in input_path_dict.keys():
        input_paths_to_sample.append(input_path)
print(len(input_paths_to_sample))

# get the paths to the inputs for which I have less than 5 designs
for input_path, num_occurrences in input_path_dict.items():
    if num_occurrences < 5:
        input_paths_to_sample.append(input_path)
print(len(input_paths_to_sample))

with open("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter/to_sample.list", 'w') as f:
    f.write('\n'.join(input_paths_to_sample))
# Out:
# 75
# 1381

# %%
# Also need to generate a list of designs for which I haven't updated loop distances. This is everything in scores.json for 02_design_filter.
with open("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter/to_update_loop_dist.list", 'w') as f:
    f.write('\n'.join(scores_df.index))

# %%
os.chdir("/home/broerman/projects/crispy_shifty")
# Python standard library
import os
import pwd
import socket
import sys

# 3rd party library imports
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# Rosetta library imports
from pyrosetta.distributed.cluster.core import PyRosettaCluster

# Custom library imports
from pyrosetta.distributed import requires_init
from typing import *
from pyrosetta.distributed.packed_pose.core import PackedPose
sys.path.insert(0, os.getcwd())
# wrap a function to distribute
@requires_init
def score_loop_dist_wrapper(
    packed_pose_in: Optional[PackedPose] = None, **kwargs
) -> Generator[PackedPose, PackedPose, None]:
    import pyrosetta
    import pyrosetta.distributed.io as io
    from crispy_shifty.protocols.cleaning import path_to_pose_or_ppose
    from crispy_shifty.protocols.design import score_loop_dist

    # generate poses or convert input packed pose into pose
    if packed_pose_in is not None:
        poses = [io.to_pose(packed_pose_in)]
        pdb_path = "none"
    else:
        pdb_path = kwargs["pdb_path"]
        poses = path_to_pose_or_ppose(
            path=pdb_path, cluster_scores=True, pack_result=False
        )

    for pose in poses:
        print("Scoring loop distance...", end="")
        pre_break_helix = int(float(pose.scores["pre_break_helix"]))
        score_loop_dist(pose, pre_break_helix, name="loop_dist_A")
        score_loop_dist(pose, 3*pre_break_helix, name="loop_dist_B")
        print("complete.")

        ppose = io.to_packed(pose)
        yield ppose

print(f"View dashboard at http://{socket.gethostname()}:8787")

selected = "/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter/to_update_loop_dist.list"

options = {
    "-out:level": "100",
    "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
    "-indexed_structure_store:fragment_store": "/net/databases/VALL_clustered/connect_chains/ss_grouped_vall_helix_shortLoop.h5",
    "-precompute_ig": "true"
}

output_path = os.path.join(os.getcwd(), "projects/crispy_shifty_dimers/02_design_filter_2")
os.makedirs(output_path, exist_ok=True)

if __name__ == "__main__":
    # configure SLURM cluster as a context manager
    with SLURMCluster(
        cores=1,
        processes=1,
        job_cpu=1,
        memory="3GB",
        queue="short",
        walltime="2:30:00",
        death_timeout=120,
        local_directory="$TMPDIR",  # spill worker litter on local node temp storage
        log_directory=os.path.join(output_path, "slurm_logs"),
        extra=["--lifetime", "3h", "--lifetime-stagger", "5m"],
    ) as cluster:
        print(cluster.job_script())
        # scale between 1-100 workers,
        cluster.adapt(
            minimum=1,
            maximum=100,
            wait_count=999,  # Number of consecutive times that a worker should be suggested for removal it is removed
            interval="5s",  # Time between checks
            target_duration="60s",
        )
        # setup a client to interact with the cluster as a context manager
        with Client(cluster) as client:
            print(client)
            PyRosettaCluster(
                client=client,
                logging_level="ERROR",
                output_path=output_path,
                project_name="crispy_shifty_dimers",
                scratch_dir=output_path,
                simulation_name="02_design_filter",
                tasks=create_tasks(selected, options),
                nstruct=1,
            ).distribute(protocols=[score_loop_dist_wrapper])
            client.close()
        cluster.scale(0)
        cluster.close()
    print("distributed run complete")
# Out:
# View dashboard at http://dig107:8787
# #!/usr/bin/env bash
#
# #SBATCH -J dask-worker
# #SBATCH -e /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/slurm_logs/dask-worker-%J.err
# #SBATCH -o /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/slurm_logs/dask-worker-%J.out
# #SBATCH -p short
# #SBATCH -n 1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem=3G
# #SBATCH -t 2:30:00
#
# /projects/crispy_shifty/envs/crispy/bin/python -m distributed.cli.dask_worker tcp://172.16.131.211:44421 --nthreads 1 --memory-limit 2.79GiB --name dummy-name --nanny --death-timeout 120 --local-directory $TMPDIR --lifetime 3h --lifetime-stagger 5m --protocol tcp://
#
# <Client: 'tcp://172.16.131.211:44421' processes=0 threads=0, memory=0 B>
# WARNING:root:`conda env export --prefix /projects/crispy_shifty/envs/crispy` did not run successfully, so the active conda environment YML file string was not saved! It is recommended to run:
# `conda env export --prefix /projects/crispy_shifty/envs/crispy > environment.yml`
# to reproduce this simulation later.
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7ff8f9a387c0>>, <Task finished name='Task-1334697' coro=<Cluster._sync_cluster_info() done, defined at /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/deploy/cluster.py:104> exception=CommClosedError("Exception while trying to call remote method 'set_metadata' before comm was established.")>)
# Traceback (most recent call last):
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/comm/tcp.py", line 205, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/core.py", line 787, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/core.py", line 640, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) rpc.set_metadata local=tcp://172.16.131.211:46048 remote=tcp://172.16.131.211:44421>: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/deploy/cluster.py", line 105, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/distributed/core.py", line 790, in send_recv_from_rpc
#     raise type(e)(
# distributed.comm.core.CommClosedError: Exception while trying to call remote method 'set_metadata' before comm was established.
# distributed run complete

# %%
# Finish sampling 

os.chdir("/home/broerman/projects/crispy_shifty")

# PyRosettaCluster needs to initialize an empty pose object if the job failed. This will fail if pyrosetta is not initialized, stopping the whole run.
pyrosetta.distributed.maybe_init(**{
    "options": "-corrections::beta_nov16 true",
    "extra_options":{
        "-out:level": "300",
        "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
        "-indexed_structure_store:fragment_store": "/home/bcov/sc/scaffold_comparison/data/ss_grouped_vall_all.h5",
        "-precompute_ig": "true",
        "-run:constant_seed": "1"
}})

# Python standard library
import os
import pwd
import socket
import sys

# 3rd party library imports
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# Rosetta library imports
from pyrosetta.distributed.cluster.core import PyRosettaCluster

# Custom library imports
sys.path.insert(0, os.getcwd())
from crispy_shifty.protocols.design import one_state_design_unlooped_dimer  # the functions we will distribute

print(f"View dashboard at http://{socket.gethostname()}:8787")

selected = os.path.join(os.getcwd(), "projects/crispy_shifty_dimers/02_design_filter/to_sample.list")

options = {
    "-out:level": "100",
    "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
    "-indexed_structure_store:fragment_store": "/net/databases/VALL_clustered/connect_chains/ss_grouped_vall_helix_shortLoop.h5",
    "-precompute_ig": "true"
}

output_path = os.path.join(os.getcwd(), "projects/crispy_shifty_dimers/02_design_filter_2")
os.makedirs(output_path, exist_ok=True)

if __name__ == "__main__":
    # configure SLURM cluster as a context manager
    with SLURMCluster(
        cores=1,
        processes=1,
        job_cpu=1,
        memory="10GB",
        queue="medium",
        walltime="23:30:00",
        death_timeout=120,
        local_directory="$TMPDIR",  # spill worker litter on local node temp storage
        log_directory=os.path.join(output_path, "slurm_logs"),
        extra=["--lifetime", "23h", "--lifetime-stagger", "5m"],
    ) as cluster:
        print(cluster.job_script())
        # scale between 1-1000 workers,
        cluster.adapt(
            minimum=1,
            maximum=1000,
            wait_count=999,  # Number of consecutive times that a worker should be suggested for removal it is removed
            interval="5s",  # Time between checks
            target_duration="60s",
        )
        # setup a client to interact with the cluster as a context manager
        with Client(cluster) as client:
            print(client)
            client.upload_file(
                os.path.join(os.getcwd(), "crispy_shifty/protocols/design.py")
            )  # upload the script that contains the functions to distribute
            PyRosettaCluster(
                client=client,
                logging_level="ERROR",
                output_path=output_path,
                project_name="crispy_shifty_dimers",
                scratch_dir=output_path,
                simulation_name="02_design_filter",
                tasks=create_tasks(selected, options),
                nstruct=5,
                ignore_errors=True # for large runs so that the head process doesn't die due to a rare segfault in one of its children
            ).distribute(protocols=[one_state_design_unlooped_dimer])
            client.close()
        cluster.scale(0)
        cluster.close()
    print("distributed run complete")
# Out:
# View dashboard at http://dig147:8787
# #!/usr/bin/env bash
#
# #SBATCH -J dask-worker
# #SBATCH -e /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/slurm_logs/dask-worker-%J.err
# #SBATCH -o /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/slurm_logs/dask-worker-%J.out
# #SBATCH -p medium
# #SBATCH -n 1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem=10G
# #SBATCH -t 23:30:00
#
# /projects/crispy_shifty/envs/crispy/bin/python -m distributed.cli.dask_worker tcp://172.16.131.31:41627 --nthreads 1 --memory-limit 9.31GiB --name dummy-name --nanny --death-timeout 120 --local-directory $TMPDIR --lifetime 23h --lifetime-stagger 5m --protocol tcp://
#
# <Client: 'tcp://172.16.131.31:41627' processes=0 threads=0, memory=0 B>
# WARNING:root:`conda env export --prefix /projects/crispy_shifty/envs/crispy` did not run successfully, so the active conda environment YML file string was not saved! It is recommended to run:
# `conda env export --prefix /projects/crispy_shifty/envs/crispy > environment.yml`
# to reproduce this simulation later.
# core.conformation.Conformation: [ WARNING ] Attempted to determine the residue type set of an empty pose.
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 983 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 1.77606 seconds.

# %%
# Actually finish sampling (the above cell had problems with slurm, so I used array tasks instead)

from crispy_shifty.utils.io import gen_array_tasks

design_list_file = "/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter/to_sample.list"
output_path = "/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3"

# Format as a string of key value pairs with no leading dashes on the argument names
options = "out:level 100 holes:dalphaball /home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc indexed_structure_store:fragment_store /home/bcov/sc/scaffold_comparison/data/ss_grouped_vall_all.h5 precompute_ig true"

gen_array_tasks(distribute_func='crispy_shifty.protocols.design.one_state_design_unlooped_dimer',
                design_list_file=design_list_file,
                output_path=output_path,
                queue='medium',
                memory='10G',
                nstruct=5,
                options=options,
                simulation_name='02_design_filter')

# gen_array_tasks('protocols.design.one_state_design_unlooped_dimer',
#                 design_list_file,
#                 output_path,
#                 'medium')
# Out:
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# Run the following command with your desired environment active:
# sbatch -a 1-$(cat /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/tasks.cmds | wc -l) /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/run.sh

# %%
from crispy_shifty.utils.io import collect_score_file
output_path = "/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3"
collect_score_file(output_path, 'scores')

# %%
# Fix how some of the score values are missing quotation marks, which causes problems down the road with my existing filtering code
# Only need to run once

import os

def quote_scorefile(scores_file, output_file):
    import json
    with open(scores_file, 'r') as f:
        with open(output_file, 'a') as out:
            for line in f:
                data = json.loads(line)
                # print(data)
                
                for scores_dict in data.values(): # just one value in the dict
                    for key, value in scores_dict.items():
                        scores_dict[key] = str(value)
                    for key, value in data.items(): # just one item in the dict
                        data[key] = scores_dict
                    # print(data)
                    out.write(json.dumps(data) + '\n')

os.chdir("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers")
output_path_1 = os.path.join(os.getcwd(), "02_design_filter_2")
output_path_2 = os.path.join(os.getcwd(), "02_design_filter_3")

combined_path = os.path.join(output_path_2, "combined_scores.json")
if os.path.exists(combined_path):
    os.remove(combined_path)

scores_1 = os.path.join(output_path_1, "scores.json")
quote_scorefile(scores_1, combined_path)
scores_2 = os.path.join(output_path_2, "scores.json")
quote_scorefile(scores_2, combined_path)

# %%
# Now that I've sufficiently sampled most of the inputs, read the new final scorefiles and filter

def read_scorefile(scores):
    import pandas as pd

    scores = pd.read_json(scores, orient="records", typ="frame", lines=True)
    scores = scores.T
    mat = scores.values
    n = mat.shape[0]
    dicts = list(mat[range(n), range(n)])
    index = scores.index
    tabulated_scores = pd.DataFrame(dicts, index=index)
    return tabulated_scores

os.chdir("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers")
output_path_2 = os.path.join(os.getcwd(), "02_design_filter_3")
combined_path = os.path.join(output_path_2, "combined_scores.json")
scores_df = read_scorefile(combined_path)

scores_df
# Out:
#                                                               bb_clash  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   386.6686706542969
# /mnt/home/broerman/projects/crispy_shifty/proje...   3342.748291015625
# /mnt/home/broerman/projects/crispy_shifty/proje...      3802.966796875
# /mnt/home/broerman/projects/crispy_shifty/proje...  112.13159942626953
# /mnt/home/broerman/projects/crispy_shifty/proje...   87.74484252929688
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...    1110.69873046875
# /home/broerman/projects/crispy_shifty/projects/...     1470.1923828125
# /home/broerman/projects/crispy_shifty/projects/...   653.8175659179688
# /home/broerman/projects/crispy_shifty/projects/...  149.28628540039062
# /home/broerman/projects/crispy_shifty/projects/...    4511.69287109375
#
#                                                             bb_clash_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   82.80949401855469
# /mnt/home/broerman/projects/crispy_shifty/proje...     3297.4052734375
# /mnt/home/broerman/projects/crispy_shifty/proje...   34.87366485595703
# /mnt/home/broerman/projects/crispy_shifty/proje...  52.383209228515625
# /mnt/home/broerman/projects/crispy_shifty/proje...   43.72983169555664
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...   55.77094268798828
# /home/broerman/projects/crispy_shifty/projects/...   136.7066192626953
# /home/broerman/projects/crispy_shifty/projects/...   63.83613204956055
# /home/broerman/projects/crispy_shifty/projects/...  104.71414184570312
# /home/broerman/projects/crispy_shifty/projects/...   49.17835235595703
#
#                                                             bb_clash_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   303.8587341308594
# /mnt/home/broerman/projects/crispy_shifty/proje...  45.342857360839844
# /mnt/home/broerman/projects/crispy_shifty/proje...   60.75569152832031
# /mnt/home/broerman/projects/crispy_shifty/proje...  52.383209228515625
# /mnt/home/broerman/projects/crispy_shifty/proje...   43.48370361328125
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...   55.77094268798828
# /home/broerman/projects/crispy_shifty/projects/...   640.7794189453125
# /home/broerman/projects/crispy_shifty/projects/...  52.213924407958984
# /home/broerman/projects/crispy_shifty/projects/...  44.572139739990234
# /home/broerman/projects/crispy_shifty/projects/...   49.17835235595703
#
#                                                              cms_ac_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  40.377952575683594
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.4830004870891571
# /mnt/home/broerman/projects/crispy_shifty/proje...   338.9127502441406
# /mnt/home/broerman/projects/crispy_shifty/proje...                -1.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                -1.0
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...                -1.0
# /home/broerman/projects/crispy_shifty/projects/...                -1.0
# /home/broerman/projects/crispy_shifty/projects/...                -1.0
# /home/broerman/projects/crispy_shifty/projects/...                -1.0
# /home/broerman/projects/crispy_shifty/projects/...                -1.0
#
#                                                                cms_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   273.8495178222656
# /mnt/home/broerman/projects/crispy_shifty/proje...  172.35617065429688
# /mnt/home/broerman/projects/crispy_shifty/proje...   244.4143524169922
# /mnt/home/broerman/projects/crispy_shifty/proje...    333.374267578125
# /mnt/home/broerman/projects/crispy_shifty/proje...   406.4630126953125
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...   566.0570678710938
# /home/broerman/projects/crispy_shifty/projects/...   985.1359252929688
# /home/broerman/projects/crispy_shifty/projects/...   562.4816284179688
# /home/broerman/projects/crispy_shifty/projects/...   642.1607666015625
# /home/broerman/projects/crispy_shifty/projects/...    472.663818359375
#
#                                                             cms_dhr_ac  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   350.3719177246094
# /mnt/home/broerman/projects/crispy_shifty/proje...  172.35617065429688
# /mnt/home/broerman/projects/crispy_shifty/proje...   347.3058166503906
# /mnt/home/broerman/projects/crispy_shifty/proje...   595.5352783203125
# /mnt/home/broerman/projects/crispy_shifty/proje...   537.9674682617188
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...   739.2079467773438
# /home/broerman/projects/crispy_shifty/projects/...  1478.9134521484375
# /home/broerman/projects/crispy_shifty/projects/...   692.9485473632812
# /home/broerman/projects/crispy_shifty/projects/...   493.4500732421875
# /home/broerman/projects/crispy_shifty/projects/...   643.0289306640625
#
#                                                             cms_dhr_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  212.23387145996094
# /mnt/home/broerman/projects/crispy_shifty/proje...         554.2578125
# /mnt/home/broerman/projects/crispy_shifty/proje...  260.10772705078125
# /mnt/home/broerman/projects/crispy_shifty/proje...   879.2686157226562
# /mnt/home/broerman/projects/crispy_shifty/proje...   595.2611083984375
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...   752.7520751953125
# /home/broerman/projects/crispy_shifty/projects/...  1499.6646728515625
# /home/broerman/projects/crispy_shifty/projects/...   776.1315307617188
# /home/broerman/projects/crispy_shifty/projects/...   479.1233215332031
# /home/broerman/projects/crispy_shifty/projects/...    737.514892578125
#
#                                                    dhr_ac_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             20.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             11.0
# /mnt/home/broerman/projects/crispy_shifty/proje...              5.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             35.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             30.0
# ...                                                             ...
# /home/broerman/projects/crispy_shifty/projects/...             41.0
# /home/broerman/projects/crispy_shifty/projects/...             63.0
# /home/broerman/projects/crispy_shifty/projects/...             32.0
# /home/broerman/projects/crispy_shifty/projects/...             32.0
# /home/broerman/projects/crispy_shifty/projects/...             31.0
#
#                                                    dhr_bn_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             10.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             19.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             25.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             42.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             25.0
# ...                                                             ...
# /home/broerman/projects/crispy_shifty/projects/...             33.0
# /home/broerman/projects/crispy_shifty/projects/...             78.0
# /home/broerman/projects/crispy_shifty/projects/...             41.0
# /home/broerman/projects/crispy_shifty/projects/...             22.0
# /home/broerman/projects/crispy_shifty/projects/...             37.0
#
#                                                    dhr_int_count  ... shift_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          14.0  ...     2.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          13.0  ...     5.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          16.0  ...     1.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          10.0  ...     1.0
# /mnt/home/broerman/projects/crispy_shifty/proje...          21.0  ...     6.0
# ...                                                          ...  ...     ...
# /home/broerman/projects/crispy_shifty/projects/...          17.0  ...    -1.0
# /home/broerman/projects/crispy_shifty/projects/...          35.0  ...     1.0
# /home/broerman/projects/crispy_shifty/projects/...          13.0  ...     5.0
# /home/broerman/projects/crispy_shifty/projects/...          14.0  ...     6.0
# /home/broerman/projects/crispy_shifty/projects/...          12.0  ...    -1.0
#
#                                                    shift_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...     6.0
# /mnt/home/broerman/projects/crispy_shifty/proje...    -5.0
# /mnt/home/broerman/projects/crispy_shifty/proje...    -2.0
# /mnt/home/broerman/projects/crispy_shifty/proje...    -1.0
# /mnt/home/broerman/projects/crispy_shifty/proje...     1.0
# ...                                                    ...
# /home/broerman/projects/crispy_shifty/projects/...     1.0
# /home/broerman/projects/crispy_shifty/projects/...    -5.0
# /home/broerman/projects/crispy_shifty/projects/...    -1.0
# /home/broerman/projects/crispy_shifty/projects/...    -6.0
# /home/broerman/projects/crispy_shifty/projects/...     1.0
#
#                                                                  ss_sc  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.7084348201751709
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.7809131741523743
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.7064631581306458
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.7397868633270264
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.6989730596542358
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...  0.7312727570533752
# /home/broerman/projects/crispy_shifty/projects/...   0.731054961681366
# /home/broerman/projects/crispy_shifty/projects/...  0.7514273524284363
# /home/broerman/projects/crispy_shifty/projects/...  0.7377557754516602
# /home/broerman/projects/crispy_shifty/projects/...  0.7498043179512024
#
#                                                            total_score  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  14914.797802444302
# /mnt/home/broerman/projects/crispy_shifty/proje...  14685.350251101356
# /mnt/home/broerman/projects/crispy_shifty/proje...  24340.686150542846
# /mnt/home/broerman/projects/crispy_shifty/proje...   24361.19121252997
# /mnt/home/broerman/projects/crispy_shifty/proje...  28511.317616899487
# ...                                                                ...
# /home/broerman/projects/crispy_shifty/projects/...   43236.34212913024
# /home/broerman/projects/crispy_shifty/projects/...   85781.07705172154
# /home/broerman/projects/crispy_shifty/projects/...   42337.26549994248
# /home/broerman/projects/crispy_shifty/projects/...  28973.009794713456
# /home/broerman/projects/crispy_shifty/projects/...  30023.370148917104
#
#                                                                   wnm_1  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.32737863063812256
# /mnt/home/broerman/projects/crispy_shifty/proje...    0.320171594619751
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.19964301586151123
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.16451048851013184
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.28433459997177124
# ...                                                                 ...
# /home/broerman/projects/crispy_shifty/projects/...   0.4142918884754181
# /home/broerman/projects/crispy_shifty/projects/...  0.36744269728660583
# /home/broerman/projects/crispy_shifty/projects/...   0.3666360080242157
# /home/broerman/projects/crispy_shifty/projects/...   0.3612675070762634
# /home/broerman/projects/crispy_shifty/projects/...   0.2058848738670349
#
#                                                                   wnm_2  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.3035939037799835
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.27292415499687195
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.21609383821487427
# /mnt/home/broerman/projects/crispy_shifty/proje...    0.213532492518425
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.33653366565704346
# ...                                                                 ...
# /home/broerman/projects/crispy_shifty/projects/...   0.4061988294124603
# /home/broerman/projects/crispy_shifty/projects/...   0.3999641239643097
# /home/broerman/projects/crispy_shifty/projects/...    0.503564715385437
# /home/broerman/projects/crispy_shifty/projects/...  0.37622714042663574
# /home/broerman/projects/crispy_shifty/projects/...   0.2348145991563797
#
#                                                                   wnm_3  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.33877745270729065
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.3349522054195404
# /mnt/home/broerman/projects/crispy_shifty/proje...    0.554388165473938
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.18715107440948486
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.3578997254371643
# ...                                                                 ...
# /home/broerman/projects/crispy_shifty/projects/...  0.44527366757392883
# /home/broerman/projects/crispy_shifty/projects/...  0.35502827167510986
# /home/broerman/projects/crispy_shifty/projects/...   0.4645583927631378
# /home/broerman/projects/crispy_shifty/projects/...  0.44161728024482727
# /home/broerman/projects/crispy_shifty/projects/...   0.2647167146205902
#
#                                                                   wnm_4  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.3090043365955353
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.28421998023986816
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.37920188903808594
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.1808456927537918
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.36610665917396545
# ...                                                                 ...
# /home/broerman/projects/crispy_shifty/projects/...  0.36307838559150696
# /home/broerman/projects/crispy_shifty/projects/...  0.37787315249443054
# /home/broerman/projects/crispy_shifty/projects/...   0.4614095091819763
# /home/broerman/projects/crispy_shifty/projects/...   0.2930283546447754
# /home/broerman/projects/crispy_shifty/projects/...  0.32908812165260315
#
#                                                                 wnm_hlx  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.09491097182035446
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.08948347717523575
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.15006273984909058
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.12925782799720764
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.17163214087486267
# ...                                                                 ...
# /home/broerman/projects/crispy_shifty/projects/...   0.1291550099849701
# /home/broerman/projects/crispy_shifty/projects/...  0.14009679853916168
# /home/broerman/projects/crispy_shifty/projects/...  0.18930543959140778
# /home/broerman/projects/crispy_shifty/projects/...  0.18972735106945038
# /home/broerman/projects/crispy_shifty/projects/...  0.11267230659723282
#
#                                                             yhh_planarity
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.0015607019201308026
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...      2.427922419985616
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# ...                                                                   ...
# /home/broerman/projects/crispy_shifty/projects/...                    0.0
# /home/broerman/projects/crispy_shifty/projects/...                    0.0
# /home/broerman/projects/crispy_shifty/projects/...                    0.0
# /home/broerman/projects/crispy_shifty/projects/...                    0.0
# /home/broerman/projects/crispy_shifty/projects/...                    0.0
#
# [20063 rows x 61 columns]

# %%
scores_df['parent'].nunique()
# Out:
# 213

# %%
# Compute derivative scores

scores_df['de_1_4'] = scores_df['score_14'].astype(float) - scores_df['score_1'].astype(float) - scores_df['score_4'].astype(float)
scores_df['de_14_2'] = scores_df['score_124'].astype(float) - scores_df['score_14'].astype(float) - scores_df['score_2'].astype(float)
scores_df['de_14_3'] = scores_df['score_134'].astype(float) - scores_df['score_14'].astype(float) - scores_df['score_3'].astype(float)
scores_df['de_2_3'] = scores_df['score_23'].astype(float) - scores_df['score_2'].astype(float) - scores_df['score_3'].astype(float)
scores_df['wnm'] = scores_df[['wnm_1', 'wnm_2', 'wnm_3', 'wnm_4']].max(axis=1)
scores_df['delta_loop_dist_A'] = scores_df['loop_dist_A'].astype(float) - scores_df['parent_loop_dist'].astype(float)
scores_df['delta_loop_dist_B'] = scores_df['loop_dist_B'].astype(float) - scores_df['parent_loop_dist'].astype(float)

# %%
import sys
sys.path.insert(0, '/home/broerman/projects/crispy_shifty/')
from crispy_shifty.plotting.utils import histplot_df

cols = [
        "cms_dhr",
        "cms_dhr_ac",
        "cms_dhr_bn",
        "cms_ac_bn",
        "de_1_4",
        "de_14_2",
        "de_14_3",
        "de_2_3",
        "score_per_res",
        "delta_loop_dist_A",
        "delta_loop_dist_B",
        "wnm",
        "wnm_1",
        "wnm_2",
        "wnm_3",
        "wnm_4",
        "wnm_hlx",
        "ss_sc",
        "sc_dhr",
        "sc_dhr_ac",
        "sc_dhr_bn",
        "sc_ac_bn"
    #     "parent",
    ]

# make sure all the columns to plot are numeric
scores_df[cols] = scores_df[cols].astype(float)
histplot_df(scores_df, cols=cols, bins=100)
# Out:
# 22it [00:02,  8.69it/s]

# %%
def filter_df(df, cutoffs):
    filtered_df = df

    for score_term, cutoff, greaterthan in cutoffs:
        if greaterthan:
            filtered_df = filtered_df[filtered_df[score_term] > cutoff]
        else:
            filtered_df = filtered_df[filtered_df[score_term] < cutoff]

    print(len(filtered_df))
    
    return filtered_df

def filter_df_delta(df, parent_df, delta_cutoffs):
    filtered_df = df

    for score_term, parent_term, cutoff, greaterthan in delta_cutoffs:
        filtered_series = filtered_df[score_term]
        parent_scores = parent_df.loc[filtered_df['parent'], parent_term]
        parent_scores.index = filtered_series.index
        # print(filtered_series)
        # print(parent_scores)
        # print(parent_scores - filtered_series < cutoff)
        if greaterthan:
            filtered_df = filtered_df[filtered_series - parent_scores > -cutoff]
        else:
            filtered_df = filtered_df[filtered_series - parent_scores < cutoff]
    
    print(len(filtered_df))
    
    return filtered_df

# %%
# Filter designs- remove worst by worst9mer and whether the designs are exploded

cutoffs = [('cms_dhr', 1, 1),
           ('cms_dhr_ac', 1, 1),
           ('cms_dhr_bn', 1, 1),
           ('wnm', 0.4, 0),
           ('wnm_hlx', 0.15, 0)
]

filtered_df = filter_df(scores_df, cutoffs)
# Out:
# 9748

# %%
filtered_df['parent'].nunique()
# Out:
# 176

# %%
histplot_df(filtered_df, cols=cols, bins=100)
# Out:
# 22it [00:02,  9.14it/s]

# %%
# Print some designs with a low cms_dhr to see what's going on
filtered_df[(filtered_df['cms_dhr'] < 250) & (filtered_df['cms_dhr'] > 100)].head()
# Out:
#                                                               bb_clash  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   3342.748291015625
# /mnt/home/broerman/projects/crispy_shifty/proje...   1768.426025390625
# /mnt/home/broerman/projects/crispy_shifty/proje...  101.75830841064453
# /mnt/home/broerman/projects/crispy_shifty/proje...  117.68179321289062
# /mnt/home/broerman/projects/crispy_shifty/proje...    284.741943359375
#
#                                                             bb_clash_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...     3297.4052734375
# /mnt/home/broerman/projects/crispy_shifty/proje...   34.77348327636719
# /mnt/home/broerman/projects/crispy_shifty/proje...   40.49620056152344
# /mnt/home/broerman/projects/crispy_shifty/proje...   45.54097366333008
# /mnt/home/broerman/projects/crispy_shifty/proje...  240.59005737304688
#
#                                                             bb_clash_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  45.342857360839844
# /mnt/home/broerman/projects/crispy_shifty/proje...     1672.2900390625
# /mnt/home/broerman/projects/crispy_shifty/proje...  40.557247161865234
# /mnt/home/broerman/projects/crispy_shifty/proje...   72.13697814941406
# /mnt/home/broerman/projects/crispy_shifty/proje...   44.15187454223633
#
#                                                     cms_ac_bn     cms_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.483000  172.356171
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  157.622955
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  136.587479
# /mnt/home/broerman/projects/crispy_shifty/proje...  10.553129  229.766373
# /mnt/home/broerman/projects/crispy_shifty/proje...  -1.000000  194.681885
#
#                                                     cms_dhr_ac  cms_dhr_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  172.356171  554.257812
# /mnt/home/broerman/projects/crispy_shifty/proje...  499.079773  359.177399
# /mnt/home/broerman/projects/crispy_shifty/proje...  174.148849  604.038330
# /mnt/home/broerman/projects/crispy_shifty/proje...  422.049255  761.922424
# /mnt/home/broerman/projects/crispy_shifty/proje...  230.821686  476.038879
#
#                                                    dhr_ac_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             11.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             18.0
# /mnt/home/broerman/projects/crispy_shifty/proje...              8.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             15.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             11.0
#
#                                                    dhr_bn_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             19.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             26.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             29.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             38.0
# /mnt/home/broerman/projects/crispy_shifty/proje...              7.0
#
#                                                    dhr_int_count  ...  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          13.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          21.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          17.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          18.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          10.0  ...
#
#                                                        wnm_4   wnm_hlx  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.284220  0.089483
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.288063  0.136389
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.211732  0.109092
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.283505  0.115204
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.278152  0.101630
#
#                                                             yhh_planarity  \
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                    0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...  7.841247984252675e-09
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.011352269318261943
#
#                                                        de_1_4    de_14_2  \
# /mnt/home/broerman/projects/crispy_shifty/proje... -58.232925 -30.852478
# /mnt/home/broerman/projects/crispy_shifty/proje... -64.345970 -79.559921
# /mnt/home/broerman/projects/crispy_shifty/proje... -56.955475 -31.532455
# /mnt/home/broerman/projects/crispy_shifty/proje... -70.646164 -60.071442
# /mnt/home/broerman/projects/crispy_shifty/proje... -66.088638 -32.908875
#
#                                                        de_14_3    de_2_3  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  -89.713928  0.112335
# /mnt/home/broerman/projects/crispy_shifty/proje...  -62.742615  0.000015
# /mnt/home/broerman/projects/crispy_shifty/proje...  -95.561768  0.000015
# /mnt/home/broerman/projects/crispy_shifty/proje... -122.189270 -0.738861
# /mnt/home/broerman/projects/crispy_shifty/proje...  -74.176590 -0.000015
#
#                                                          wnm  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.334952
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.389461
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.221579
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.364781
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.293735
#
#                                                    delta_loop_dist_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...         -0.791585
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.725537
# /mnt/home/broerman/projects/crispy_shifty/proje...          3.343186
# /mnt/home/broerman/projects/crispy_shifty/proje...         -0.793242
# /mnt/home/broerman/projects/crispy_shifty/proje...          5.555347
#
#                                                    delta_loop_dist_B
# /mnt/home/broerman/projects/crispy_shifty/proje...          4.074121
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.776847
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.620572
# /mnt/home/broerman/projects/crispy_shifty/proje...          4.757802
# /mnt/home/broerman/projects/crispy_shifty/proje...          4.347504
#
# [5 rows x 68 columns]

# %%
parent_path = os.path.join(os.getcwd(), "00_inputs")
parent_scores = os.path.join(parent_path, "scaffold_scores.json")
parent_df = read_scorefile(parent_scores)
parent_df.set_index('name', inplace=True) # replaces the indexing by path to indexing by name
parent_df.head()
# Out:
#           cms_dhr  dslf_fa13       fa_atr  fa_dun_dev  fa_dun_rot  \
# name
# DHR79  465.784760        0.0 -1400.636238   20.246144  145.179909
# DHR39  321.138519        0.0 -1021.834993   17.066784  143.013018
# DHR82  521.558899        0.0 -1498.559091   21.318266  188.024945
# DHR53  357.954865        0.0 -1060.006597   10.302994  129.002023
# DHR54  401.634857        0.0 -1047.650966   13.488556  126.581043
#
#        fa_dun_semi     fa_elec  fa_intra_atr_xover4  fa_intra_elec  \
# name
# DHR79   274.889648 -579.788253           -75.762132     -46.974228
# DHR39   193.845212 -399.394071           -59.330212     -31.171610
# DHR82   262.872950 -583.674273           -79.204600     -40.859747
# DHR53   184.958473 -407.824125           -53.968461     -22.101187
# DHR54   188.660628 -426.607112           -60.735843     -40.887647
#
#        fa_intra_rep_xover4  ...       score     score_1    score_12  \
# name                        ...
# DHR79            73.894970  ... -561.677002 -245.034546 -561.677002
# DHR39            63.490618  ... -385.315033 -170.901306 -385.315033
# DHR82            99.079365  ... -621.641541 -269.689850 -621.641541
# DHR53            61.719093  ... -457.311920 -204.453018 -457.311920
# DHR54            66.710380  ... -449.422302 -189.710556 -449.422302
#
#           score_2  score_per_res     ss_sc  total_score     wnm_1     wnm_2  \
# name
# DHR79 -251.905350      -2.553077  0.698439  -561.676986  0.322625  0.316925
# DHR39 -169.123169      -2.335243  0.731973  -385.315035  0.377876  0.327590
# DHR82 -283.966553      -2.726498  0.744233  -621.641546  0.226993  0.237057
# DHR53 -195.076950      -2.722095  0.788842  -457.311918  0.384927  0.392240
# DHR54 -196.766571      -2.643661  0.702949  -449.422302  0.279068  0.318838
#
#         wnm_hlx
# name
# DHR79  0.094490
# DHR39  0.085988
# DHR82  0.110452
# DHR53  0.087457
# DHR54  0.076508
#
# [5 rows x 39 columns]

# %%
# Plots distributions of delta scores between the parent and the children.
# Delta scores are calculated by design_value - parent_value.
# For scores which I'm trying to maximize, higher delta values are better.
# Conclusion: all score_per_res are better than the parents, and sc and cms usually increase, even for the side domains!
# Only cms_dhr decreases significantly from the parent.
# So, let's just filter based on whether designs are as good as or better than the parent (cutoffs at 0).

delta_pairs = [('cms_dhr', 'cms_dhr'),
               ('cms_dhr_ac', 'cms_dhr'),
               ('cms_dhr_bn', 'cms_dhr'),
               ('score_per_res', 'score_per_res'),
               ('ss_sc', 'ss_sc'),
               ('sc_dhr', 'sc_dhr'),
               ('sc_dhr_ac', 'sc_dhr'),
               ('sc_dhr_bn', 'sc_dhr')]

score_terms, parent_terms = tuple(map(list, zip(*delta_pairs)))
# gets the columns to filter on from the parent df, then duplicate rows by parent such that rows correspond to the parents of the rows of filtered df
parent_aligned_df = parent_df[parent_terms].loc[filtered_df['parent'], :]
parent_aligned_df.index = filtered_df.index
parent_aligned_df.columns = score_terms # fixes an issue with duplicate column names, and makes sure the output columns are correctly named
delta_df = filtered_df[score_terms] - parent_aligned_df

fig, axs = plt.subplots(2, 4, figsize=(20,10))

for col, ax in tqdm(zip(score_terms, axs.flatten())):
    sns.histplot(
        data=delta_df,
        x=col,
        ax=ax,
#         kde=True
#         hue='parent'
        bins=100
    )

plt.tight_layout()
# Out:
# 0it [00:00, ?it/s]

# %%
# Print some designs with a lower cms_dhr than the parent to see what's going on
delta_df[(delta_df['cms_dhr'] < -100) & (delta_df['cms_dhr'] > -130)].head()

# Looks like the presence of the side domains causes the parent dhr interface to shrink, with fewer boundary contacts.
# Apolar only cms could be a better metric here, though it will also be skewed since with the side domains,
# apolar residues could be placed on the boundary of the parent dhr interface.
# I think the solution is to use a lenient delta cutoff for the cms parent dhr interface, say 100, to allow a little bit of interface shrinkage.
# Out:
#                                                        cms_dhr  cms_dhr_ac  \
# /mnt/home/broerman/projects/crispy_shifty/proje... -128.324829  -15.476837
# /mnt/home/broerman/projects/crispy_shifty/proje... -103.946136 -103.946136
# /mnt/home/broerman/projects/crispy_shifty/proje... -109.094025   18.668335
# /mnt/home/broerman/projects/crispy_shifty/proje... -100.655853  -75.516815
# /mnt/home/broerman/projects/crispy_shifty/proje... -110.717682  166.518494
#
#                                                     cms_dhr_bn  score_per_res  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  -11.097046      -0.464113
# /mnt/home/broerman/projects/crispy_shifty/proje...  277.955505      -0.399581
# /mnt/home/broerman/projects/crispy_shifty/proje...  -62.761383      -0.511388
# /mnt/home/broerman/projects/crispy_shifty/proje...  174.447723      -0.298625
# /mnt/home/broerman/projects/crispy_shifty/proje...  166.639526      -0.368412
#
#                                                        ss_sc    sc_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.029996  0.149985
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.011160  0.049645
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.045362  0.109118
# /mnt/home/broerman/projects/crispy_shifty/proje... -0.008390  0.005022
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.038626  0.064437
#
#                                                     sc_dhr_ac  sc_dhr_bn
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.049623   0.176675
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.035773   0.069932
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.179763   0.006487
# /mnt/home/broerman/projects/crispy_shifty/proje...  -0.020437   0.047412
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.031934   0.063684

# %%
# And some designs with a higher cms_dhr than the parent
delta_df[(delta_df['cms_dhr'] > 100) & (delta_df['cms_dhr'] < 200)].head()
# Out:
#                                                        cms_dhr  cms_dhr_ac  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  117.482407  126.579025
# /mnt/home/broerman/projects/crispy_shifty/proje...  124.810333  161.839264
# /mnt/home/broerman/projects/crispy_shifty/proje...  149.607880  201.059631
# /mnt/home/broerman/projects/crispy_shifty/proje...  192.689819  255.290955
# /mnt/home/broerman/projects/crispy_shifty/proje...  139.716431  291.310547
#
#                                                     cms_dhr_bn  score_per_res  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  361.987137      -0.617763
# /mnt/home/broerman/projects/crispy_shifty/proje...   21.770935      -0.266335
# /mnt/home/broerman/projects/crispy_shifty/proje...   37.525909      -0.484502
# /mnt/home/broerman/projects/crispy_shifty/proje...  -90.790558      -0.438677
# /mnt/home/broerman/projects/crispy_shifty/proje...  159.460968      -1.081181
#
#                                                        ss_sc    sc_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.086550  0.229636
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.001674  0.067127
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.042451  0.178258
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.032071  0.179362
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.089481  0.202259
#
#                                                     sc_dhr_ac  sc_dhr_bn
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.196603   0.216418
# /mnt/home/broerman/projects/crispy_shifty/proje...  -0.010735  -0.060917
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.110098   0.126626
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.103441  -0.052351
# /mnt/home/broerman/projects/crispy_shifty/proje...   0.111226   0.146697

# %%
# how do I determine these cutoffs? Look at distributions of delta cutoffs between the parent and the children

# here, "cutoff" means "if the design scores worse than the parent by x"
delta_cutoffs = [('cms_dhr', 'cms_dhr', 100, 1),
                 ('cms_dhr_ac', 'cms_dhr', 0, 1),
                 ('cms_dhr_bn', 'cms_dhr', 0, 1),
                 ('score_per_res', 'score_per_res', 0.2, 0),
                 ('ss_sc', 'ss_sc', 0, 1),
                 ('sc_dhr', 'sc_dhr', 0, 1),
                 ('sc_dhr_ac', 'sc_dhr', 0, 1),
                 ('sc_dhr_bn', 'sc_dhr', 0, 1)]

delta_filtered_df = filter_df_delta(filtered_df, parent_df, delta_cutoffs)
# Out:
# 5980

# %%
delta_filtered_df['parent'].nunique()
# Out:
# 144

# %%
delta_filtered_df.head()
# Out:
#                                                               bb_clash  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  100.22811889648438
# /mnt/home/broerman/projects/crispy_shifty/proje...   261.9366149902344
# /mnt/home/broerman/projects/crispy_shifty/proje...  1356.5601806640625
# /mnt/home/broerman/projects/crispy_shifty/proje...   2617.639892578125
# /mnt/home/broerman/projects/crispy_shifty/proje...   559.2636108398438
#
#                                                             bb_clash_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   50.11375427246094
# /mnt/home/broerman/projects/crispy_shifty/proje...  37.129581451416016
# /mnt/home/broerman/projects/crispy_shifty/proje...  1312.4459228515625
# /mnt/home/broerman/projects/crispy_shifty/proje...   945.3499145507812
# /mnt/home/broerman/projects/crispy_shifty/proje...   49.52986526489258
#
#                                                             bb_clash_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   50.11375427246094
# /mnt/home/broerman/projects/crispy_shifty/proje...  37.129581451416016
# /mnt/home/broerman/projects/crispy_shifty/proje...   44.11418533325195
# /mnt/home/broerman/projects/crispy_shifty/proje...     1672.2900390625
# /mnt/home/broerman/projects/crispy_shifty/proje...   269.9587707519531
#
#                                                     cms_ac_bn     cms_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  417.987396
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  316.494171
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  552.996399
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  254.665039
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  621.645264
#
#                                                     cms_dhr_ac  cms_dhr_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  518.198914  585.848511
# /mnt/home/broerman/projects/crispy_shifty/proje...  573.662842  421.352203
# /mnt/home/broerman/projects/crispy_shifty/proje...  574.881348  474.947296
# /mnt/home/broerman/projects/crispy_shifty/proje...  327.875763  381.594666
# /mnt/home/broerman/projects/crispy_shifty/proje...  663.730713  661.339478
#
#                                                    dhr_ac_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             23.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             28.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             39.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             13.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             30.0
#
#                                                    dhr_bn_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             22.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             20.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             24.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             26.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             55.0
#
#                                                    dhr_int_count  ...  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          20.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          19.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          18.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          21.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          16.0  ...
#
#                                                        wnm_4   wnm_hlx  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.310289  0.128212
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.391887  0.117004
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.244698  0.101567
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.233850  0.131140
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.203909  0.112960
#
#                                                    yhh_planarity     de_1_4  \
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -84.854980
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -49.306679
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -67.792114
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -63.413788
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -88.466980
#
#                                                        de_14_2     de_14_3  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  -85.005432 -114.374527
# /mnt/home/broerman/projects/crispy_shifty/proje...  -97.840134  -69.341370
# /mnt/home/broerman/projects/crispy_shifty/proje...  -88.441864  -74.894226
# /mnt/home/broerman/projects/crispy_shifty/proje...  -43.370636  -67.999695
# /mnt/home/broerman/projects/crispy_shifty/proje... -106.258636 -108.620361
#
#                                                       de_2_3       wnm  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000015  0.310289
# /mnt/home/broerman/projects/crispy_shifty/proje... -0.000015  0.391887
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000000  0.298287
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000000  0.265801
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000000  0.251911
#
#                                                    delta_loop_dist_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...         -5.059126
# /mnt/home/broerman/projects/crispy_shifty/proje...         -0.586154
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.825097
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.100627
# /mnt/home/broerman/projects/crispy_shifty/proje...         -1.501627
#
#                                                    delta_loop_dist_B
# /mnt/home/broerman/projects/crispy_shifty/proje...          4.324197
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.463285
# /mnt/home/broerman/projects/crispy_shifty/proje...          5.000660
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.266287
# /mnt/home/broerman/projects/crispy_shifty/proje...          5.080668
#
# [5 rows x 68 columns]

# %%
histplot_df(delta_filtered_df, cols=cols, bins=50)
# Out:
# 22it [00:01, 13.14it/s]

# %%
# Print some of the second cms peak to see if they are THRs.
filtered_df[(filtered_df['cms_dhr'] > 900)].head()
# Out:
#                                                               bb_clash  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  1858.6153564453125
# /mnt/home/broerman/projects/crispy_shifty/proje...   710.5448608398438
# /mnt/home/broerman/projects/crispy_shifty/proje...     1161.6591796875
# /mnt/home/broerman/projects/crispy_shifty/proje...    4684.25537109375
# /mnt/home/broerman/projects/crispy_shifty/proje...        4361.7734375
#
#                                                             bb_clash_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   136.7066192626953
# /mnt/home/broerman/projects/crispy_shifty/proje...   93.95706939697266
# /mnt/home/broerman/projects/crispy_shifty/proje...   93.95706939697266
# /mnt/home/broerman/projects/crispy_shifty/proje...  415.87322998046875
# /mnt/home/broerman/projects/crispy_shifty/proje...   93.39134216308594
#
#                                                            bb_clash_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  136.7066192626953
# /mnt/home/broerman/projects/crispy_shifty/proje...  93.95706939697266
# /mnt/home/broerman/projects/crispy_shifty/proje...    1067.7021484375
# /mnt/home/broerman/projects/crispy_shifty/proje...   4268.38232421875
# /mnt/home/broerman/projects/crispy_shifty/proje...   4268.38232421875
#
#                                                     cms_ac_bn      cms_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0   931.114014
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0   919.657104
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0   957.721863
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  1039.502075
# /mnt/home/broerman/projects/crispy_shifty/proje...       -1.0  1017.487244
#
#                                                      cms_dhr_ac   cms_dhr_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  1324.395630  1379.208618
# /mnt/home/broerman/projects/crispy_shifty/proje...  1308.585327  1495.255249
# /mnt/home/broerman/projects/crispy_shifty/proje...  1382.148315  1471.747925
# /mnt/home/broerman/projects/crispy_shifty/proje...  1210.291504  1311.909180
# /mnt/home/broerman/projects/crispy_shifty/proje...  1382.243408  1308.317993
#
#                                                    dhr_ac_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             73.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             56.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             56.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             59.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             61.0
#
#                                                    dhr_bn_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             67.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             75.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             84.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             79.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             79.0
#
#                                                    dhr_int_count  ...  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          35.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          31.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          31.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          32.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          32.0  ...
#
#                                                        wnm_4   wnm_hlx  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.386356  0.118572
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.304422  0.119503
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.318141  0.114490
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.388562  0.122882
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.364463  0.124909
#
#                                                    yhh_planarity      de_1_4  \
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -170.655701
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -178.142487
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -173.107483
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -169.250641
# /mnt/home/broerman/projects/crispy_shifty/proje...           0.0 -158.107056
#
#                                                        de_14_2     de_14_3  \
# /mnt/home/broerman/projects/crispy_shifty/proje... -220.189880 -222.227295
# /mnt/home/broerman/projects/crispy_shifty/proje... -211.855896 -242.634674
# /mnt/home/broerman/projects/crispy_shifty/proje... -219.464722 -238.964111
# /mnt/home/broerman/projects/crispy_shifty/proje... -201.625244 -199.020660
# /mnt/home/broerman/projects/crispy_shifty/proje... -230.215424 -205.285248
#
#                                                       de_2_3       wnm  \
# /mnt/home/broerman/projects/crispy_shifty/proje... -0.000061  0.386356
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000031  0.355099
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000000  0.334877
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000031  0.388562
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.000000  0.394730
#
#                                                    delta_loop_dist_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.836477
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.524035
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.538482
# /mnt/home/broerman/projects/crispy_shifty/proje...          0.671074
# /mnt/home/broerman/projects/crispy_shifty/proje...         -0.491061
#
#                                                    delta_loop_dist_B
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.814585
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.423097
# /mnt/home/broerman/projects/crispy_shifty/proje...          0.990540
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.295882
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.295882
#
# [5 rows x 68 columns]

# %%
# Nope, they're actually super long TH_DHRs.
# Did any THRs make it? Yes!
filtered_df[(filtered_df['pre_break_helix'] == '6.0')].head()
# Out:
#                                                               bb_clash  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   668.2564086914062
# /mnt/home/broerman/projects/crispy_shifty/proje...   152.4293670654297
# /mnt/home/broerman/projects/crispy_shifty/proje...  1858.6153564453125
# /mnt/home/broerman/projects/crispy_shifty/proje...  292.32464599609375
# /mnt/home/broerman/projects/crispy_shifty/proje...  343.88153076171875
#
#                                                             bb_clash_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   79.41667938232422
# /mnt/home/broerman/projects/crispy_shifty/proje...    76.1240463256836
# /mnt/home/broerman/projects/crispy_shifty/proje...   136.7066192626953
# /mnt/home/broerman/projects/crispy_shifty/proje...  142.95269775390625
# /mnt/home/broerman/projects/crispy_shifty/proje...  194.50958251953125
#
#                                                            bb_clash_B  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  76.21759033203125
# /mnt/home/broerman/projects/crispy_shifty/proje...   76.3053207397461
# /mnt/home/broerman/projects/crispy_shifty/proje...  136.7066192626953
# /mnt/home/broerman/projects/crispy_shifty/proje...  149.3719482421875
# /mnt/home/broerman/projects/crispy_shifty/proje...  149.3719482421875
#
#                                                      cms_ac_bn     cms_dhr  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  517.715881  307.120026
# /mnt/home/broerman/projects/crispy_shifty/proje...  312.245422  357.603577
# /mnt/home/broerman/projects/crispy_shifty/proje...   -1.000000  931.114014
# /mnt/home/broerman/projects/crispy_shifty/proje...  248.159149  421.329895
# /mnt/home/broerman/projects/crispy_shifty/proje...  305.212189  459.352905
#
#                                                      cms_dhr_ac   cms_dhr_bn  \
# /mnt/home/broerman/projects/crispy_shifty/proje...   307.120026   536.304993
# /mnt/home/broerman/projects/crispy_shifty/proje...   357.603577   811.348511
# /mnt/home/broerman/projects/crispy_shifty/proje...  1324.395630  1379.208618
# /mnt/home/broerman/projects/crispy_shifty/proje...   421.329895   790.366211
# /mnt/home/broerman/projects/crispy_shifty/proje...   459.352905   733.136169
#
#                                                    dhr_ac_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             19.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             19.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             73.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             29.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             28.0
#
#                                                    dhr_bn_int_count  \
# /mnt/home/broerman/projects/crispy_shifty/proje...             35.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             33.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             67.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             43.0
# /mnt/home/broerman/projects/crispy_shifty/proje...             43.0
#
#                                                    dhr_int_count  ...  \
# /mnt/home/broerman/projects/crispy_shifty/proje...          11.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          15.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          35.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          23.0  ...
# /mnt/home/broerman/projects/crispy_shifty/proje...          23.0  ...
#
#                                                        wnm_4   wnm_hlx  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.365453  0.116165
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.355521  0.143304
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.386356  0.118572
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.383369  0.121529
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.354774  0.142260
#
#                                                              yhh_planarity  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  5.1897351971419425e-09
# /mnt/home/broerman/projects/crispy_shifty/proje...                     0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                     0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                     0.0
# /mnt/home/broerman/projects/crispy_shifty/proje...                     0.0
#
#                                                         de_1_4     de_14_2  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  -88.877502  -50.799286
# /mnt/home/broerman/projects/crispy_shifty/proje... -125.721466  -56.937469
# /mnt/home/broerman/projects/crispy_shifty/proje... -170.655701 -220.189880
# /mnt/home/broerman/projects/crispy_shifty/proje... -123.729431  -66.783966
# /mnt/home/broerman/projects/crispy_shifty/proje... -118.002136  -69.143097
#
#                                                        de_14_3     de_2_3  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  -86.879150 -88.783539
# /mnt/home/broerman/projects/crispy_shifty/proje... -138.479797 -43.052338
# /mnt/home/broerman/projects/crispy_shifty/proje... -222.227295  -0.000061
# /mnt/home/broerman/projects/crispy_shifty/proje... -130.769470 -34.588898
# /mnt/home/broerman/projects/crispy_shifty/proje... -117.863068 -48.407532
#
#                                                          wnm  \
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.369996
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.380786
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.386356
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.391315
# /mnt/home/broerman/projects/crispy_shifty/proje...  0.395654
#
#                                                    delta_loop_dist_A  \
# /mnt/home/broerman/projects/crispy_shifty/proje...         -2.610209
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.667954
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.836477
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.311994
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.647608
#
#                                                    delta_loop_dist_B
# /mnt/home/broerman/projects/crispy_shifty/proje...          3.678906
# /mnt/home/broerman/projects/crispy_shifty/proje...          2.055666
# /mnt/home/broerman/projects/crispy_shifty/proje...          1.814585
# /mnt/home/broerman/projects/crispy_shifty/proje...         -0.613650
# /mnt/home/broerman/projects/crispy_shifty/proje...         -0.613650
#
# [5 rows x 68 columns]

# %%
filtered_json_path = os.path.join(output_path_2, "filtered_designs.json")
delta_filtered_df.to_json(filtered_json_path)
filtered_list_path = os.path.join(output_path_2, "filtered_designs.list")
with open(filtered_list_path, 'w') as f:
    f.write('\n'.join(delta_filtered_df.index))

# %%
# print 50 random designs to load into pymol, just to check that everything looks good.
print(';'.join('load ' + path for path in delta_filtered_df.sample(50).index))

# Overall, these all look great!
# I could try filtering more on delta_loop_dist (this gets high particularly for B), but since looping is so fast, I think I'll just loop
# everything and see how delta_loop_dist is correlated with loop success later.
# Out:
# load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0004/_d721c6a1eced45caab60d0c7e112bbc1.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0006/_2094821188164cd98f573aaa97aab4ea.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0000/_83f3ea3887c143b7bbe4bbeeb1273634.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0003/_c880ca1648964de7aa113b4827a1fb67.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0011/02_design_filter_f4fe4ae2892b4e6daefe257e16037303.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0000/02_design_filter_41933ebfe5ac4a41bd27eba4e002b4a1.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0009/02_design_filter_71885731b12e433ba0181a19474adfc6.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0005/02_design_filter_7cd44c26689e4cb0b1df7f7bd7c7ebae.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0011/02_design_filter_bae5c7f5c2874d279554c921a9f86d9d.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0004/_6fad4ba4d33641d99c5f930aacb69b79.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0006/02_design_filter_f95e466215e04bd7897519698d46e138.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0003/_731f5a321d5740edb6ca92accfaa0bee.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0003/_1ca7f597e0d2427295461b766b43b40b.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0005/02_design_filter_3cedce19841445fcabf037a20ed06438.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0012/02_design_filter_62be0a148edb4e7db6286d1cdd1c0fa6.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0005/02_design_filter_0589bc40c0b344219d4645fb6fd3230a.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0009/02_design_filter_6e58362475374cc79d59b1bda07b8080.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0001/02_design_filter_816ecfa1c9104f72883aaedc469e0312.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0000/02_design_filter_7f70a08d70484e719dcb68e7e89a0073.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0005/02_design_filter_260caee1036547f9ba16e3a63b0c28ea.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0007/02_design_filter_7bc1f275c31646b6a981156c3b165f09.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0001/_fc238ced7c5b448ca8642f2ac3691f3e.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0001/02_design_filter_258c9b33c0de492285db181a0ca66890.pdb.bz2;load /mnt/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_2/decoys/0008/02_design_filter_bbfc3217fe574bf2a4ca7c922ab1cb34.pdb.bz2;load /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/02_design_filter_3/decoys/0001/_42b38b24f7cd4abe972bd6c9341b65b2.pdb.bz2;load /mnt/home/broerman/projec ...

# %% [markdown]
# ## Everything after this is for testing ##

# %%
from copy import deepcopy
test_df = deepcopy(filtered_df)

# %%
# testing

sys.path.insert(0, "/home/broerman/projects/crispy_shifty")
from crispy_shifty.protocols.design import one_state_design_unlooped_dimer

pyrosetta.distributed.maybe_init(**{
    "options": "-corrections::beta_nov16 true",
    "extra_options":{
        "-out:level": "100",
        "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
        "-indexed_structure_store:fragment_store": "/home/bcov/sc/scaffold_comparison/data/ss_grouped_vall_all.h5",
        "-precompute_ig": "true"
}})

import pyrosetta.distributed.io as io
file = '/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/01_make_states/decoys/0000/CSD_01_make_states_4c315eabb34a449a886b9e9bd9b8227a.pdb.bz2'

for i in tqdm(range(1)):
    pposes = one_state_design_unlooped_dimer(None, **{'pdb_path': file})
    for ppose in pposes:
        designed_pose = io.to_pose(ppose)
        # designed_pose.dump_pdb(f"/home/broerman/projects/dimeric_hinges/dimeric_hinges_2/testing/02_design_filter/X23_3_20_3_ct7_fc.pdb")
        designed_pose.dump_pdb(f"/home/broerman/projects/dimeric_hinges/dimeric_hinges_2/testing/02_design_filter/X23_3_20_3_ct7_fc_fixbb2_{i:02d}.pdb")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0.00 min: Generated interface selector
# 0.00 min: Generated interface design task factory
# 0.06 min: Generated score functions
# 0.06 min: Generated movemaps
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# select design_sel, (chain A and resid 2,6,28,31,32,35,38,39,42,46,49,50,51,52,54,55,56,58,59,61,62,65,66,69,73,75,77,78,80,81,82,84,85,87,88,89,90,91,92,93,94,95) or (chain B and resid 103,106,107,109,110,113,114,117,122,123,125,126,127,129,130,132,133,134,136,137,140,182) or (chain C and resid 245,247,248,251,252,254,255,256,258,259,262,263,265,266,268,270,271,274,275,277,278,279,281,282,284,285) or (chain D and resid 289,290,291,292,293,294,295,296,297,299,300,301,303,304,306,307,308,310,315,318,319,322,323,325,326,327,329,330,332,333,334,342,346,349,350,353,356,360)
# 0.21 min: Generating structure profile...complete.
# 0.21 min: Starting 1 round of fixed backbone design...complete.
# 36.09 min: Starting 2 rounds of flexible backbone design...complete.
# 36.09 min: Clearing constraints...complete.
# 36.09 min: Scoring contact molecular surface and shape complementarity...core.scoring.sc.ShapeComplementarityCalculator: {0} [ ERROR ] Failed: No molecular dots generated!
# protocols.simple_filters.ShapeComplementarityFilter: {0} [ ERROR ] Issue running shape complementarity calculator - returning -1 instead.
# complete.
# 36.18 min: Scoring secondary structure shape complementarity...complete.
# 36.84 min: Scoring per_chain worst9mer...complete.
# 40.28 min: Scoring helical worst9mer...complete.
# 40.55 min: Scoring...complete.
# 40.56 min: Scoring contact molecular surface...core.scoring.sc.ContactMolecularSurfaceCalculator: {0} [ ERROR ] Failed: No molecular dots generated!
# protocols.simple_filters.ContactMolecularSurfaceFilter: {0} [ ERROR ] Issue running shape complementarity calculator - returning -1 instead.
# complete.

# %%
# testing

sys.path.insert(0, "/home/broerman/projects/crispy_shifty")
from crispy_shifty.protocols.design import one_state_design_unlooped_dimer

pyrosetta.distributed.maybe_init(**{
    "options": "-corrections::beta_nov16 true",
    "extra_options":{
        "-out:level": "100",
        "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
        "-indexed_structure_store:fragment_store": "/home/bcov/sc/scaffold_comparison/data/ss_grouped_vall_all.h5",
        "-precompute_ig": "true"
}})

import pyrosetta.distributed.io as io
file = '/home/broerman/projects/dimeric_hinges/dimeric_hinges_2/testing/01_make_states/DHR21/DHR21_A_-1_0_DHR21_B_1_1.pdb'

for i in tqdm(range(1)):
    pposes = one_state_design_unlooped_dimer(None, **{'pdb_path': file})
    for ppose in pposes:
        designed_pose = io.to_pose(ppose)
        # designed_pose.dump_pdb(f"/home/broerman/projects/dimeric_hinges/dimeric_hinges_2/testing/02_design_filter/X23_3_20_3_ct7_fc.pdb")
        designed_pose.dump_pdb(f"/home/broerman/projects/dimeric_hinges/dimeric_hinges_2/testing/02_design_filter/DHR21_{i:02d}.pdb")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0.00 min: Generated interface selector
# 0.00 min: Generated interface design task factory
# 0.06 min: Generated score functions
# 0.06 min: Generated movemaps
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# select design_sel, (chain A and resid 2,5,9,25,28,38,39,40,42,43,44,46,47,50,51,54,55,59,60,62,63,64,66,67,69,70,71,73) or (chain B and resid 74,76,77,78,80,81,82,84,85,87,88,96,100,103,104,107,108) or (chain C and resid 151,187,188,189,190,192,193,195,196,197,199,200,203,204,208,209,211,212,213,215,216,217,218,219,220,221,222) or (chain D and resid 224,226,227,229,230,231,233,234,235,236,237,238,240,245,246,247,249,250,252,253,254,256,257,259,268,269,272,275,276)
# 0.22 min: Generating structure profile...complete.
# 5.91 min: Starting 1 round of fixed backbone design...complete.
# 32.86 min: Starting 2 rounds of flexible backbone design...complete.
# 88.69 min: Clearing constraints...complete.
# 88.69 min: Scoring contact molecular surface and shape complementarity...core.scoring.sc.ShapeComplementarityCalculator: {0} [ ERROR ] Failed: No molecular dots generated!
# protocols.simple_filters.ShapeComplementarityFilter: {0} [ ERROR ] Issue running shape complementarity calculator - returning -1 instead.
# complete.
# 88.80 min: Scoring secondary structure shape complementarity...complete.
# 89.45 min: Scoring per_chain worst9mer...complete.
# 89.54 min: Scoring helical worst9mer...complete.
# 89.71 min: Scoring...complete.
# 89.72 min: Scoring contact molecular surface...core.scoring.sc.ContactMolecularSurfaceCalculator: {0} [ ERROR ] Failed: No molecular dots generated!
# protocols.simple_filters.ContactMolecularSurfaceFilter: {0} [ ERROR ] Issue running shape complementarity calculator - returning -1 instead.
# complete.
