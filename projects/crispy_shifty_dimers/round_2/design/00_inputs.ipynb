# %% [markdown]
# # Score the inputs for parent-specific filters later

# %%
# %load_ext lab_black
# Python standard library
from glob import glob
import os
import socket
import sys

# 3rd party library imports
import dask
import matplotlib.pyplot as plt
import pandas as pd
import pyrosetta
import numpy as np
import scipy
import seaborn as sns
from tqdm.auto import tqdm  # jupyter compatible progress bar

tqdm.pandas()  # link tqdm to pandas
# Notebook magic
# save plots in the notebook
# %matplotlib inline
# reloads modules automatically before executing cells
# %load_ext autoreload
# %autoreload 2
print(f"running in directory: {os.getcwd()}")  # where are we?
print(f"running on node: {socket.gethostname()}")  # what node are we on?
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# running in directory: /home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers
# running on node: sofia

# %%
os.chdir("/home/broerman/projects/crispy_shifty")
sys.path.insert(0, os.getcwd())

# %%
input_dhrs = [os.path.join(os.getcwd(), 'projects/crispy_shifty_dimers/00_inputs/original_dhr.list'),
              os.path.join(os.getcwd(), 'projects/crispy_shifty_dimers/00_inputs/tj_DHRs_filtered_filtered.list')]
input_thrs = [os.path.join(os.getcwd(), 'projects/crispy_shifty_dimers/00_inputs/original_thr.list')]

def create_tasks():
    for list_file in input_dhrs:
        with open(list_file, "r") as f:
            for file in f:
                file = file.rstrip()
                tasks = {}
                tasks["pdb_path"] = file
                tasks["pre_break_helix"] = 4 # use kwargs to match the right pre_break_helix with the right scaffold type
                tasks["name"] = file.split('/')[-1][:-4]
                yield tasks

    for list_file in input_thrs:
        with open(list_file, "r") as f:
            for file in f:
                file = file.rstrip()
                tasks = {}
                tasks["pdb_path"] = file
                tasks["pre_break_helix"] = 6 # use kwargs to match the right pre_break_helix with the right scaffold type
                tasks["name"] = file.split('/')[-1][:-4]
                yield tasks

# %%
with open(input_dhrs[1], 'r') as f:
    print(len(f.readlines()))
# Out:
# 190

# %%
# Python standard library
from typing import *

# 3rd party library imports
# Rosetta library imports
from pyrosetta.distributed.packed_pose.core import PackedPose
from pyrosetta.rosetta.core.pose import Pose

def measure_CA_dist(pose: Pose, resi_a: int, resi_b: int) -> float:
    resi_a_coords = pose.residue(resi_a).xyz("CA")
    resi_b_coords = pose.residue(resi_b).xyz("CA")
    dist = resi_a_coords.distance(resi_b_coords)
    return dist


def helix_dict_maker(pose: Pose) -> dict:
    """
    Make a dictionary mapping of residue indices to the helix indices.
    Keys are helix indices, values are lists of residue indices.
    """
    import pyrosetta

    ss = pyrosetta.rosetta.core.scoring.dssp.Dssp(pose)
    helix_dict = {}
    n = 1
    for i in range(1, len(pose.sequence())):
        if (ss.get_dssp_secstruct(i) == "H") & (ss.get_dssp_secstruct(i - 1) != "H"):
            helix_dict[n] = [i]
        if (ss.get_dssp_secstruct(i) == "H") & (ss.get_dssp_secstruct(i + 1) != "H"):
            helix_dict[n].append(i)
            n += 1
    return helix_dict


def get_helix_endpoints(pose: Pose, n_terminal: bool) -> dict:
    """
    Make a dictionary of the start (n_terminal=True) or end residue indices of each helix
    """
    helix_dict = helix_dict_maker(pose)
    helix_endpoints = {}
    if n_terminal:
        index = 0  # helix start residue
    else:
        index = -1  # helix end residue
    for helix, residue_list in helix_dict.items():
        helix_endpoints[helix] = residue_list[index]
    return helix_endpoints


def combine_two_poses(
    pose_a: Pose,
    pose_b: Pose,
    end_a: int,
    start_b: int,
) -> Pose:
    """
    Make a new pose, containing pose_a up to end_a, then pose_b starting from start_b
    Assumes pose_a has only one chain.
    """
    import pyrosetta
    from pyrosetta.rosetta.core.pose import Pose

    length = len(pose_a.sequence())
    newpose = Pose()
    for i in range(1, end_a + 1):
        newpose.append_residue_by_bond(pose_a.residue(i))
    newpose.append_residue_by_jump(
        pose_b.residue(start_b), newpose.chain_end(1), "CA", "CA", 1
    )
    for i in range(start_b + 1, length + 1):
        newpose.append_residue_by_bond(pose_b.residue(i))
    return newpose

def score_inputs(output_scorefile, **kwargs):

    import collections
    import json
    from time import time
    import pyrosetta
    import pyrosetta.distributed.io as io
    from crispy_shifty.protocols.cleaning import path_to_pose_or_ppose
    from crispy_shifty.protocols.design import score_cms, score_sc, score_ss_sc, score_on_chain_subset, score_per_res, score_wnm_all, score_wnm_helix, gen_score_filter

    # testing to properly set the TMPDIR on distributed jobs
    # import os
    # os.environ['TMPDIR'] = '/scratch'

    start_time = time()

    def print_timestamp(print_str, end="\n", *args):
        time_min = (time() - start_time) / 60
        print(f"{time_min:.2f} min: {print_str}", end=end)
        for arg in args:
            print(arg)

    clean_sfxn = pyrosetta.create_score_function("beta_nov16.wts")
    print_timestamp("Generated score functions")

    pdb_path = kwargs["pdb_path"]
    poses = path_to_pose_or_ppose(
        path=pdb_path, cluster_scores=False, pack_result=False
    )

    for pose in poses:
        try:
            pre_break_helix = kwargs["pre_break_helix"]
        except KeyError:
            raise RuntimeError("Need to supply pre_break_helix")
        try:
            original_name = kwargs["name"]
        except KeyError:
            raise RuntimeError("Need to supply name")
        print_timestamp(
            f"Generating split pose for {original_name}...", end=""
        )
        post_break_helix = pre_break_helix + 1
        starts = get_helix_endpoints(pose, n_terminal=True)
        ends = get_helix_endpoints(pose, n_terminal=False)
        end_pose_a, start_pose_b = (ends[pre_break_helix], starts[post_break_helix])
        # Combines ensuring the domain containing the pivot helix remains aligned to the parent DHR
        split_pose = combine_two_poses(pose, pose, end_pose_a, start_pose_b)
        rechain = pyrosetta.rosetta.protocols.simple_moves.SwitchChainOrderMover()
        rechain.chain_order("12")
        rechain.apply(split_pose)
        print('complete.')

        loop_dist = measure_CA_dist(split_pose, end_pose_a, end_pose_a+1)
        pyrosetta.rosetta.core.pose.setPoseExtraScore(split_pose, "loop_dist", loop_dist)

        print_timestamp(
            "Scoring contact molecular surface and shape complementarity...", end=""
        )
        a_sel = pyrosetta.rosetta.core.select.residue_selector.ChainSelector(1)
        b_sel = pyrosetta.rosetta.core.select.residue_selector.ChainSelector(2)
        score_cms(split_pose, a_sel, b_sel, 'cms_dhr')
        score_sc(split_pose, a_sel, b_sel, "sc_dhr")
        print("complete.")

        print_timestamp("Scoring secondary structure shape complementarity...", end="")
        score_ss_sc(split_pose)
        print("complete.")
        print_timestamp("Scoring per_chain worst9mer...", end="")
        score_wnm_all(split_pose)
        print("complete.")
        print_timestamp("Scoring helical worst9mer...", end="")
        score_wnm_helix(split_pose)
        print("complete.")

        print_timestamp("Scoring...", end="")
        score_per_res(split_pose, clean_sfxn)
        score_filter = gen_score_filter(clean_sfxn)
        chain_lists = [[1], [2], [1, 2]]
        for chain_list in chain_lists:
            score_on_chain_subset(split_pose, score_filter, chain_list)
        print("complete.")

        pyrosetta.rosetta.core.pose.setPoseExtraScore(split_pose, "name", original_name)

        scores = io.to_dict(split_pose)
        scores.pop("pickled_pose", None)

        scorefile_data = json.dumps(
            {
                pdb_path: collections.OrderedDict(
                    sorted(scores.items())
                )
            }
        )
        # Write data to new scorefile per decoy
        with open(output_scorefile, "a") as f:
            f.write(scorefile_data + os.linesep)
        
        # pyrosetta.dump_pdb(split_pose, '/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers/testing/test_input_scoring.pdb')

# %%
# first iteration took about 4.5 minutes, including loading the wnm database
# running again with the database already loaded took about 41 seconds on DHR79

pyrosetta.distributed.maybe_init(**{
    "options": "-corrections::beta_nov16 true",
    "extra_options":{
        "-out:level": "100",
        "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
        "-indexed_structure_store:fragment_store": "/home/bcov/sc/scaffold_comparison/data/ss_grouped_vall_all.h5",
}})

output_scorefile = os.path.join(os.getcwd(), 'projects/crispy_shifty_dimers/00_inputs/scaffold_scores.json')

for task in tqdm(create_tasks()):
    score_inputs(output_scorefile, **task)
# Out:
# 0it [00:00, ?it/s]
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR79...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.42 min: Scoring per_chain worst9mer...complete.
# 0.46 min: Scoring helical worst9mer...complete.
# 0.65 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR39...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.23 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR82...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.48 min: Scoring per_chain worst9mer...complete.
# 0.52 min: Scoring helical worst9mer...complete.
# 0.73 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR53...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.23 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR54...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.26 min: Scoring per_chain worst9mer...complete.
# 0.30 min: Scoring helical worst9mer...complete.
# 0.43 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR21...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.22 min: Scoring per_chain worst9mer...complete.
# 0.26 min: Scoring helical worst9mer...complete.
# 0.34 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR68...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.57 min: Scoring per_chain worst9mer...complete.
# 0.61 min: Scoring helical worst9mer...complete.
# 0.83 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR71...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.37 min: Scoring per_chain worst9mer...complete.
# 0.41 min: Scoring helical worst9mer...complete.
# 0.58 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR76...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.47 min: Scoring per_chain worst9mer...complete.
# 0.51 min: Scoring helical worst9mer...complete.
# 0.70 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR64...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.48 min: Scoring per_chain worst9mer...complete.
# 0.51 min: Scoring helical worst9mer...complete.
# 0.72 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR07...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.23 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.39 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR09...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.39 min: Scoring per_chain worst9mer...complete.
# 0.44 min: Scoring helical worst9mer...complete.
# 0.59 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR57...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.33 min: Scoring per_chain worst9mer...complete.
# 0.37 min: Scoring helical worst9mer...complete.
# 0.51 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR59...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.36 min: Scoring per_chain worst9mer...complete.
# 0.40 min: Scoring helical worst9mer...complete.
# 0.54 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR10...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.36 min: Scoring per_chain worst9mer...complete.
# 0.40 min: Scoring helical worst9mer...complete.
# 0.55 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR62...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.26 min: Scoring per_chain worst9mer...complete.
# 0.29 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR08...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.30 min: Scoring per_chain worst9mer...complete.
# 0.34 min: Scoring helical worst9mer...complete.
# 0.47 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR46...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.24 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR03_nocys...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.25 min: Scoring per_chain worst9mer...complete.
# 0.28 min: Scoring helical worst9mer...complete.
# 0.40 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR01_nocys...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.26 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR07_nocys...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.24 min: Scoring per_chain worst9mer...complete.
# 0.28 min: Scoring helical worst9mer...complete.
# 0.39 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR26_nocys...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.46 min: Scoring per_chain worst9mer...complete.
# 0.50 min: Scoring helical worst9mer...complete.
# 0.68 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR52_nocys...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.32 min: Scoring helical worst9mer...complete.
# 0.44 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR24_nocys...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.34 min: Scoring per_chain worst9mer...complete.
# 0.38 min: Scoring helical worst9mer...complete.
# 0.51 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for DHR18_nocys...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.55 min: Scoring per_chain worst9mer...complete.
# 0.59 min: Scoring helical worst9mer...complete.
# 0.80 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for DHR15_nocys...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.34 min: Scoring per_chain worst9mer...complete.
# 0.39 min: Scoring helical worst9mer...complete.
# 0.51 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR54_5CWL...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.25 min: Scoring per_chain worst9mer...complete.
# 0.29 min: Scoring helical worst9mer...complete.
# 0.40 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR71_5CWN...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.35 min: Scoring per_chain worst9mer...complete.
# 0.39 min: Scoring helical worst9mer...complete.
# 0.55 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR53_5CWK...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.22 min: Scoring per_chain worst9mer...complete.
# 0.26 min: Scoring helical worst9mer...complete.
# 0.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for hDHR76_5CWO...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.46 min: Scoring per_chain worst9mer...complete.
# 0.50 min: Scoring helical worst9mer...complete.
# 0.69 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for hDHR64_5CWM...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.48 min: Scoring per_chain worst9mer...complete.
# 0.52 min: Scoring helical worst9mer...complete.
# 0.72 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR10_5CWG...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.37 min: Scoring per_chain worst9mer...complete.
# 0.42 min: Scoring helical worst9mer...complete.
# 0.56 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR9_HFuse...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.39 min: Scoring per_chain worst9mer...complete.
# 0.43 min: Scoring helical worst9mer...complete.
# 0.57 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for KH_R4_PXX13...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.25 min: Scoring per_chain worst9mer...complete.
# 0.29 min: Scoring helical worst9mer...complete.
# 0.39 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for KH_PO11...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.32 min: Scoring helical worst9mer...complete.
# 0.45 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for KH_PEP12_PLP...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.38 min: Scoring per_chain worst9mer...complete.
# 0.42 min: Scoring helical worst9mer...complete.
# 0.59 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for hTH_DHR_DN_T6...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.41 min: Scoring per_chain worst9mer...complete.
# 0.45 min: Scoring helical worst9mer...complete.
# 0.62 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for KH_PXX28_AWP...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.31 min: Scoring per_chain worst9mer...complete.
# 0.34 min: Scoring helical worst9mer...complete.
# 0.50 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for hDHR79_5CWP...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.45 min: Scoring per_chain worst9mer...complete.
# 0.48 min: Scoring helical worst9mer...complete.
# 0.68 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR14_5CWH...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.24 min: Scoring helical worst9mer...complete.
# 0.34 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR8_5CWF...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.30 min: Scoring per_chain worst9mer...complete.
# 0.34 min: Scoring helical worst9mer...complete.
# 0.48 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR49_5CWJ...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.24 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hTH_DHR_8_NSR...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.39 min: Scoring per_chain worst9mer...complete.
# 0.43 min: Scoring helical worst9mer...complete.
# 0.59 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for hDHR14_5H7C...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.21 min: Scoring per_chain worst9mer...complete.
# 0.25 min: Scoring helical worst9mer...complete.
# 0.35 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for TH_DHR_DN-T6...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.40 min: Scoring per_chain worst9mer...complete.
# 0.43 min: Scoring helical worst9mer...complete.
# 0.60 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for TH_DHR_2_NSR...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.32 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for TH_DHR_T5...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.33 min: Scoring per_chain worst9mer...complete.
# 0.37 min: Scoring helical worst9mer...complete.
# 0.52 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.03 min: Generating split pose for TH_DHR_C9...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.17 min: Scoring secondary structure shape complementarity...complete.
# 1.23 min: Scoring per_chain worst9mer...complete.
# 1.27 min: Scoring helical worst9mer...complete.
# 1.63 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for TH_DHR_S2...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.14 min: Scoring secondary structure shape complementarity...complete.
# 1.05 min: Scoring per_chain worst9mer...complete.
# 1.10 min: Scoring helical worst9mer...complete.
# 1.45 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for TH_DHR_T7...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.32 min: Scoring helical worst9mer...complete.
# 0.46 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for TH_DHR_8_NSR...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.41 min: Scoring per_chain worst9mer...complete.
# 0.45 min: Scoring helical worst9mer...complete.
# 0.60 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for TH_DHR_C2...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.14 min: Scoring secondary structure shape complementarity...complete.
# 1.01 min: Scoring per_chain worst9mer...complete.
# 1.05 min: Scoring helical worst9mer...complete.
# 1.39 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for TH_DHR_T8...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.32 min: Scoring helical worst9mer...complete.
# 0.45 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_3_11_4_ct0_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.23 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X26_3_26_4_ct2_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.49 min: Scoring per_chain worst9mer...complete.
# 0.53 min: Scoring helical worst9mer...complete.
# 0.74 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X28_2_25_2_ct2_fb...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.52 min: Scoring per_chain worst9mer...complete.
# 0.55 min: Scoring helical worst9mer...complete.
# 0.76 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_10_1_ct4_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.15 min: Scoring per_chain worst9mer...complete.
# 0.18 min: Scoring helical worst9mer...complete.
# 0.24 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_10_1_ct24_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.11 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.18 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_14_2_ct19_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.14 min: Scoring per_chain worst9mer...complete.
# 0.17 min: Scoring helical worst9mer...complete.
# 0.23 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_3_17_1_ct7_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.19 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.31 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_2_23_4_ct3_fd...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.46 min: Scoring per_chain worst9mer...complete.
# 0.50 min: Scoring helical worst9mer...complete.
# 0.67 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_3_14_1_ct3_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.17 min: Scoring per_chain worst9mer...complete.
# 0.20 min: Scoring helical worst9mer...complete.
# 0.27 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X26_3_27_4_ct2_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.55 min: Scoring per_chain worst9mer...complete.
# 0.59 min: Scoring helical worst9mer...complete.
# 0.80 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_2_24_2_ct15_ff...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.46 min: Scoring per_chain worst9mer...complete.
# 0.50 min: Scoring helical worst9mer...complete.
# 0.68 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X26_3_24_2_ct12_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.52 min: Scoring per_chain worst9mer...complete.
# 0.56 min: Scoring helical worst9mer...complete.
# 0.76 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_3_28_3_ct2_ff...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.48 min: Scoring per_chain worst9mer...complete.
# 0.52 min: Scoring helical worst9mer...complete.
# 0.73 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_17_2_ct27_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X26_3_20_2_ct1_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.37 min: Scoring per_chain worst9mer...complete.
# 0.40 min: Scoring helical worst9mer...complete.
# 0.58 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_2_15_3_ct3_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.19 min: Scoring per_chain worst9mer...complete.
# 0.23 min: Scoring helical worst9mer...complete.
# 0.32 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X21_2_17_4_ct0_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.32 min: Scoring per_chain worst9mer...complete.
# 0.35 min: Scoring helical worst9mer...complete.
# 0.48 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X15_4_17_2_ct1_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.24 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.36 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X22_2_27_3_ct1_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.10 min: Scoring secondary structure shape complementarity...complete.
# 0.48 min: Scoring per_chain worst9mer...complete.
# 0.52 min: Scoring helical worst9mer...complete.
# 0.71 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X15_2_15_3_ct2_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.17 min: Scoring per_chain worst9mer...complete.
# 0.21 min: Scoring helical worst9mer...complete.
# 0.29 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X21_4_23_4_ct0_fg...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.44 min: Scoring per_chain worst9mer...complete.
# 0.48 min: Scoring helical worst9mer...complete.
# 0.65 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_3_14_3_ct3_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.24 min: Scoring per_chain worst9mer...complete.
# 0.26 min: Scoring helical worst9mer...complete.
# 0.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_17_1_ct21_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.16 min: Scoring per_chain worst9mer...complete.
# 0.18 min: Scoring helical worst9mer...complete.
# 0.26 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_4_10_4_ct3_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.14 min: Scoring per_chain worst9mer...complete.
# 0.18 min: Scoring helical worst9mer...complete.
# 0.22 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_3_13_4_ct0_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.15 min: Scoring per_chain worst9mer...complete.
# 0.19 min: Scoring helical worst9mer...complete.
# 0.26 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_14_3_ct24_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.21 min: Scoring per_chain worst9mer...complete.
# 0.24 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_2_10_3_ct5_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.11 min: Scoring per_chain worst9mer...complete.
# 0.15 min: Scoring helical worst9mer...complete.
# 0.19 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_3_20_3_ct3_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.36 min: Scoring per_chain worst9mer...complete.
# 0.40 min: Scoring helical worst9mer...complete.
# 0.54 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_3_18_2_ct3_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.44 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_4_11_2_ct0_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.23 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_12_3_ct0_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.18 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.31 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_3_18_2_ct13_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.43 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X12_3_10_2_ct2_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.11 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.17 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X26_3_24_2_ct17_fg...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.54 min: Scoring per_chain worst9mer...complete.
# 0.57 min: Scoring helical worst9mer...complete.
# 0.77 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X15_4_15_4_ct5_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.24 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_2_24_2_ct5_ff...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.48 min: Scoring per_chain worst9mer...complete.
# 0.51 min: Scoring helical worst9mer...complete.
# 0.69 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_3_18_4_ct6_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X26_3_24_2_ct2_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.49 min: Scoring per_chain worst9mer...complete.
# 0.52 min: Scoring helical worst9mer...complete.
# 0.72 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_4_24_1_ct1_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.45 min: Scoring per_chain worst9mer...complete.
# 0.48 min: Scoring helical worst9mer...complete.
# 0.66 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_14_1_ct12_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.14 min: Scoring per_chain worst9mer...complete.
# 0.17 min: Scoring helical worst9mer...complete.
# 0.23 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_4_13_4_ct6_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.17 min: Scoring per_chain worst9mer...complete.
# 0.21 min: Scoring helical worst9mer...complete.
# 0.27 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_2_13_3_ct10_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.15 min: Scoring per_chain worst9mer...complete.
# 0.18 min: Scoring helical worst9mer...complete.
# 0.25 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_13_2_ct6_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.18 min: Scoring per_chain worst9mer...complete.
# 0.21 min: Scoring helical worst9mer...complete.
# 0.29 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_4_12_3_ct0_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.18 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.30 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_4_18_2_ct6_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.44 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_3_19_3_ct0_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X15_3_22_3_ct6_fb...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.32 min: Scoring per_chain worst9mer...complete.
# 0.35 min: Scoring helical worst9mer...complete.
# 0.48 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_3_13_4_ct0_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.19 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.31 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_17_2_ct9_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.30 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_10_2_ct12_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.11 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.18 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_4_19_3_ct4_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.22 min: Scoring per_chain worst9mer...complete.
# 0.25 min: Scoring helical worst9mer...complete.
# 0.36 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X23_3_20_3_ct7_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.41 min: Scoring per_chain worst9mer...complete.
# 0.45 min: Scoring helical worst9mer...complete.
# 0.60 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_3_19_3_ct33_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.41 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X23_3_22_4_ct2_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.45 min: Scoring per_chain worst9mer...complete.
# 0.49 min: Scoring helical worst9mer...complete.
# 0.66 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X18_4_16_3_ct0_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.24 min: Scoring per_chain worst9mer...complete.
# 0.28 min: Scoring helical worst9mer...complete.
# 0.39 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_17_2_ct6_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.30 min: Scoring helical worst9mer...complete.
# 0.42 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_14_1_ct19_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.16 min: Scoring per_chain worst9mer...complete.
# 0.18 min: Scoring helical worst9mer...complete.
# 0.25 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X12_3_10_2_ct10_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.10 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.17 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X12_4_10_1_ct8_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.12 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.19 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X12_3_13_4_ct1_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.15 min: Scoring per_chain worst9mer...complete.
# 0.18 min: Scoring helical worst9mer...complete.
# 0.24 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X15_3_13_2_ct5_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.16 min: Scoring per_chain worst9mer...complete.
# 0.19 min: Scoring helical worst9mer...complete.
# 0.26 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X23_4_23_2_ct3_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.40 min: Scoring per_chain worst9mer...complete.
# 0.44 min: Scoring helical worst9mer...complete.
# 0.61 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X23_3_18_2_ct1_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.29 min: Scoring per_chain worst9mer...complete.
# 0.33 min: Scoring helical worst9mer...complete.
# 0.47 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_3_19_3_ct50_fb...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.25 min: Scoring per_chain worst9mer...complete.
# 0.29 min: Scoring helical worst9mer...complete.
# 0.40 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_4_15_3_ct7_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.21 min: Scoring per_chain worst9mer...complete.
# 0.25 min: Scoring helical worst9mer...complete.
# 0.34 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X24_2_24_2_ct18_fg...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.44 min: Scoring per_chain worst9mer...complete.
# 0.47 min: Scoring helical worst9mer...complete.
# 0.65 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_4_19_4_ct5_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.31 min: Scoring per_chain worst9mer...complete.
# 0.35 min: Scoring helical worst9mer...complete.
# 0.47 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X18_2_13_2_ct2_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.19 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.31 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X27_3_19_4_ct3_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.39 min: Scoring per_chain worst9mer...complete.
# 0.43 min: Scoring helical worst9mer...complete.
# 0.61 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_2_10_1_ct25_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.11 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.18 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_2_10_1_ct11_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.12 min: Scoring per_chain worst9mer...complete.
# 0.15 min: Scoring helical worst9mer...complete.
# 0.19 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_4_21_2_ct3_fd...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.28 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.43 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X16_4_15_3_ct11_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.23 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.36 min: Scoring...complete.
# ...
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_2_19_3_ct11_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.24 min: Scoring per_chain worst9mer...complete.
# 0.27 min: Scoring helical worst9mer...complete.
# 0.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X12_3_10_2_ct5_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.12 min: Scoring per_chain worst9mer...complete.
# 0.14 min: Scoring helical worst9mer...complete.
# 0.18 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_14_3_ct18_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.18 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.30 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X23_2_15_3_ct5_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.26 min: Scoring per_chain worst9mer...complete.
# 0.29 min: Scoring helical worst9mer...complete.
# 0.41 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X22_3_17_4_ct1_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.30 min: Scoring per_chain worst9mer...complete.
# 0.34 min: Scoring helical worst9mer...complete.
# 0.47 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_3_12_4_ct2_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.19 min: Scoring per_chain worst9mer...complete.
# 0.22 min: Scoring helical worst9mer...complete.
# 0.32 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X14_2_10_1_ct1_fa...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.12 min: Scoring per_chain worst9mer...complete.
# 0.15 min: Scoring helical worst9mer...complete.
# 0.19 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_14_1_ct17_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.17 min: Scoring per_chain worst9mer...complete.
# 0.20 min: Scoring helical worst9mer...complete.
# 0.28 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X18_2_14_1_ct19_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.18 min: Scoring per_chain worst9mer...complete.
# 0.20 min: Scoring helical worst9mer...complete.
# 0.29 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X21_2_18_2_ct0_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.27 min: Scoring per_chain worst9mer...complete.
# 0.31 min: Scoring helical worst9mer...complete.
# 0.43 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_14_2_ct15_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.02 min: Scoring secondary structure shape complementarity...complete.
# 0.16 min: Scoring per_chain worst9mer...complete.
# 0.19 min: Scoring helical worst9mer...complete.
# 0.28 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X20_4_23_4_ct0_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.39 min: Scoring per_chain worst9mer...complete.
# 0.43 min: Scoring helical worst9mer...complete.
# 0.58 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_2_23_3_ct8_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.40 min: Scoring per_chain worst9mer...complete.
# 0.44 min: Scoring helical worst9mer...complete.
# 0.61 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_4_19_4_ct0_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.40 min: Scoring per_chain worst9mer...complete.
# 0.44 min: Scoring helical worst9mer...complete.
# 0.59 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_13_3_ct9_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.23 min: Scoring helical worst9mer...complete.
# 0.31 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X24_3_20_4_ct2_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.40 min: Scoring per_chain worst9mer...complete.
# 0.43 min: Scoring helical worst9mer...complete.
# 0.60 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_17_2_ct2_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.25 min: Scoring per_chain worst9mer...complete.
# 0.28 min: Scoring helical worst9mer...complete.
# 0.39 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X10_3_16_4_ct13_fe...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.16 min: Scoring per_chain worst9mer...complete.
# 0.19 min: Scoring helical worst9mer...complete.
# 0.25 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X24_4_24_3_ct3_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.45 min: Scoring per_chain worst9mer...complete.
# 0.49 min: Scoring helical worst9mer...complete.
# 0.66 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_18_4_ct4_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.04 min: Scoring secondary structure shape complementarity...complete.
# 0.29 min: Scoring per_chain worst9mer...complete.
# 0.33 min: Scoring helical worst9mer...complete.
# 0.45 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_19_3_ct5_fg...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.30 min: Scoring per_chain worst9mer...complete.
# 0.33 min: Scoring helical worst9mer...complete.
# 0.46 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X28_2_18_2_ct0_fe...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.05 min: Scoring secondary structure shape complementarity...complete.
# 0.34 min: Scoring per_chain worst9mer...complete.
# 0.37 min: Scoring helical worst9mer...complete.
# 0.53 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X19_3_14_3_ct2_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.20 min: Scoring per_chain worst9mer...complete.
# 0.24 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X13_3_16_2_ct8_fd...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.16 min: Scoring per_chain worst9mer...complete.
# 0.19 min: Scoring helical worst9mer...complete.
# 0.27 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X18_3_15_3_ct6_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.30 min: Scoring per_chain worst9mer...complete.
# 0.33 min: Scoring helical worst9mer...complete.
# 0.43 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X23_4_25_4_ct0_fa...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.47 min: Scoring per_chain worst9mer...complete.
# 0.51 min: Scoring helical worst9mer...complete.
# 0.69 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for X23_4_26_3_ct8_fc...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.52 min: Scoring per_chain worst9mer...complete.
# 0.56 min: Scoring helical worst9mer...complete.
# 0.74 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_2_13_2_ct5_ff...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.17 min: Scoring per_chain worst9mer...complete.
# 0.20 min: Scoring helical worst9mer...complete.
# 0.27 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.01 min: Generating split pose for X17_3_14_3_ct23_fc...complete.
# 0.01 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.03 min: Scoring secondary structure shape complementarity...complete.
# 0.21 min: Scoring per_chain worst9mer...complete.
# 0.25 min: Scoring helical worst9mer...complete.
# 0.33 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.03 min: Generating split pose for hTHR_37...complete.
# 0.04 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.15 min: Scoring secondary structure shape complementarity...complete.
# 1.49 min: Scoring per_chain worst9mer...complete.
# 1.57 min: Scoring helical worst9mer...complete.
# 2.02 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.04 min: Generating split pose for hTHR_35_...complete.
# 0.04 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.18 min: Scoring secondary structure shape complementarity...complete.
# 1.81 min: Scoring per_chain worst9mer...complete.
# 1.87 min: Scoring helical worst9mer...complete.
# 2.38 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR13...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.73 min: Scoring per_chain worst9mer...complete.
# 0.79 min: Scoring helical worst9mer...complete.
# 1.03 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.03 min: Generating split pose for THR4...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.10 min: Scoring secondary structure shape complementarity...complete.
# 0.99 min: Scoring per_chain worst9mer...complete.
# 1.05 min: Scoring helical worst9mer...complete.
# 1.35 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR20...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.80 min: Scoring per_chain worst9mer...complete.
# 0.86 min: Scoring helical worst9mer...complete.
# 1.11 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.03 min: Generating split pose for THR3H_4...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.11 min: Scoring secondary structure shape complementarity...complete.
# 1.00 min: Scoring per_chain worst9mer...complete.
# 1.07 min: Scoring helical worst9mer...complete.
# 1.37 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR12...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.09 min: Scoring secondary structure shape complementarity...complete.
# 0.77 min: Scoring per_chain worst9mer...complete.
# 0.83 min: Scoring helical worst9mer...complete.
# 1.08 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR2...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.06 min: Scoring secondary structure shape complementarity...complete.
# 0.58 min: Scoring per_chain worst9mer...complete.
# 0.65 min: Scoring helical worst9mer...complete.
# 0.84 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR1...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.66 min: Scoring per_chain worst9mer...complete.
# 0.72 min: Scoring helical worst9mer...complete.
# 0.95 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR11...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.62 min: Scoring per_chain worst9mer...complete.
# 0.68 min: Scoring helical worst9mer...complete.
# 0.91 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR7...complete.
# 0.02 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.07 min: Scoring secondary structure shape complementarity...complete.
# 0.66 min: Scoring per_chain worst9mer...complete.
# 0.72 min: Scoring helical worst9mer...complete.
# 0.93 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR9...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.69 min: Scoring per_chain worst9mer...complete.
# 0.76 min: Scoring helical worst9mer...complete.
# 1.00 min: Scoring...complete.
# 0.00 min: Generated score functions
# 0.02 min: Generating split pose for THR22...complete.
# 0.03 min: Scoring contact molecular surface and shape complementarity...complete.
# 0.08 min: Scoring secondary structure shape complementarity...complete.
# 0.79 min: Scoring per_chain worst9mer...complete.
# 0.86 min: Scoring helical worst9mer...complete.
# 1.12 min: Scoring...complete.

# %%
def read_scorefile(scores):
    import pandas as pd

    scores = pd.read_json(scores, orient="records", typ="frame", lines=True)
    scores = scores.T
    mat = scores.values
    n = mat.shape[0]
    dicts = list(mat[range(n), range(n)])
    index = scores.index
    tabulated_scores = pd.DataFrame(dicts, index=index)
    return tabulated_scores

os.chdir("/home/broerman/projects/crispy_shifty/projects/crispy_shifty_dimers")
output_path = os.path.join(os.getcwd(), "00_inputs")
scores = os.path.join(output_path, "scaffold_scores.json")
scores_df = read_scorefile(scores)
scores_df.head()
# Out:
#                                                        cms_dhr  dslf_fa13  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  465.784760        0.0
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  321.138519        0.0
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  521.558899        0.0
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  357.954865        0.0
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  401.634857        0.0
#
#                                                          fa_atr  fa_dun_dev  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -1400.636238   20.246144
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -1021.834993   17.066784
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -1498.559091   21.318266
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -1060.006597   10.302994
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -1047.650966   13.488556
#
#                                                     fa_dun_rot  fa_dun_semi  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  145.179909   274.889648
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  143.013018   193.845212
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  188.024945   262.872950
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  129.002023   184.958473
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  126.581043   188.660628
#
#                                                        fa_elec  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -579.788253
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -399.394071
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -583.674273
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -407.824125
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -426.607112
#
#                                                     fa_intra_atr_xover4  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...           -75.762132
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...           -59.330212
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...           -79.204600
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...           -53.968461
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...           -60.735843
#
#                                                     fa_intra_elec  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...     -46.974228
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...     -31.171610
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...     -40.859747
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...     -22.101187
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...     -40.887647
#
#                                                     fa_intra_rep_xover4  ...  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...            73.894970  ...
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...            63.490618  ...
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...            99.079365  ...
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...            61.719093  ...
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...            66.710380  ...
#
#                                                          score     score_1  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -561.677002 -245.034546
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -385.315033 -170.901306
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -621.641541 -269.689850
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -457.311920 -204.453018
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -449.422302 -189.710556
#
#                                                       score_12     score_2  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -561.677002 -251.905350
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -385.315033 -169.123169
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -621.641541 -283.966553
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -457.311920 -195.076950
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo... -449.422302 -196.766571
#
#                                                     score_per_res     ss_sc  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...      -2.553077  0.698439
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...      -2.335243  0.731973
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...      -2.726498  0.744233
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...      -2.722095  0.788842
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...      -2.643661  0.702949
#
#                                                     total_score     wnm_1  \
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  -561.676986  0.322625
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  -385.315035  0.377876
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  -621.641546  0.226993
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  -457.311918  0.384927
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  -449.422302  0.279068
#
#                                                        wnm_2   wnm_hlx
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  0.316925  0.094490
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  0.327590  0.085988
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  0.237057  0.110452
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  0.392240  0.087457
# projects/crispy_shifty_dimers/00_inputs/dhrsgoo...  0.318838  0.076508
#
# [5 rows x 40 columns]

# %%
# Filter, then check whether there is significant variation among scores for designs from the same input

scores_df['de_1_2'] = scores_df['score_12'] - scores_df['score_1'] - scores_df['score_2']
scores_df['wnm'] = scores_df[['wnm_1', 'wnm_2']].max(axis=1)

def histplot_df(df):
    sns.set(
        context="talk",
        font_scale=1,  # make the font larger; default is pretty small
        style="ticks",  # make the background white with black lines
        palette="colorblind",  # a color palette that is colorblind friendly!
    )

    fig, axs = plt.subplots(3, 4, figsize=(16,12))

    cols = [
        "cms_dhr",
        "de_1_2",
        "score_per_res",
        "score",
        "wnm",
        "wnm_1",
        "wnm_2",
        "wnm_hlx",
        "ss_sc",
        "sc_dhr",
    #     "parent",
    ]

    for col, ax in tqdm(zip(cols, axs.flatten())):
        sns.histplot(
            data=df,
            x=col,
            ax=ax,
    #         kde=True
    #         hue='parent'
            # bins=100
        )

    plt.tight_layout()

# %%
histplot_df(scores_df)
# Out:
# 10it [00:00, 30.47it/s]
